# %%
import pandas as pd
import json
import codecs
import re
import gensim
import numpy as np
from os import listdir
import os
import pickle
from nltk import PorterStemmer
import random

import nltk
from nltk.stem.wordnet import WordNetLemmatizer
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import train_test_split

from sklearn.svm import LinearSVC, SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB

from sklearn.model_selection import learning_curve
from sklearn.model_selection import ShuffleSplit
import matplotlib.pyplot as plt


### Find optimal parameters for SVM - rbf
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import GridSearchCV

stoplist = set(nltk.corpus.stopwords.words("english"))
lmtzr = WordNetLemmatizer()
porter = PorterStemmer()
bigram = None
trigram = None

# %%
### Load and merge bill title and bill text data ###

bill_titles = pd.read_csv('StateBills.csv')
del bill_titles['Unnamed: 0']

wd = os.getcwd()
filepath = os.path.join(wd, 'bill_texts')
states = listdir(filepath)

states.remove('.DS_Store')

colnames = ['open_bill_id', 'bill_text']
bill_text = pd.DataFrame(columns=colnames)


for state in states:  
    print(len(bill_text), "bills so far")
    text_list = []
    bill_list = listdir(os.path.join(filepath, state))
    for bill in bill_list:
        with codecs.open(filepath + "/" + state + "/" + bill, "r", encoding='utf-8', errors='ignore') as f:
            text = f.read()
            text_list.append(text)
            
    open_bill_id = pd.Series(bill_list, name = "open_bill_id")        
    text = pd.Series(text_list, name = "bill_text")
    del text_list
    
    state_bills = pd.DataFrame([open_bill_id, text])
    state_bills = state_bills.transpose()
    bill_text = bill_text.append(state_bills)
    print(len(state_bills), "bills added for", state)
# Out:
# 0 bills so far
# 2223 bills added for ak
# 2223 bills so far
# 11348 bills added for al
# 13571 bills so far
# 8263 bills added for ar
# 21834 bills so far
# 11007 bills added for az
# 32841 bills so far
# 19707 bills added for ca
# 52548 bills so far
# 4336 bills added for co
# 56884 bills so far
# 12417 bills added for ct
# 69301 bills so far
# 4456 bills added for dc
# 73757 bills so far
# 2778 bills added for de
# 76535 bills so far
# 11870 bills added for fl
# 88405 bills so far
# 15512 bills added for ga
# 103917 bills so far
# 23998 bills added for hi
# 127915 bills so far
# 8393 bills added for ia
# 136308 bills so far
# 3708 bills added for id
# 140016 bills so far
# 93198 bills added for il
# 233214 bills so far
# 7348 bills added for in
# 240562 bills so far
# 4148 bills added for ks
# 244710 bills so far
# 7952 bills added for ky
# 252662 bills so far
# 16710 bills added for la
# 269372 bills so far
# 20303 bills added for ma
# 289675 bills so far
# 26053 bills added for md
# 315728 bills so far
# 8222 bills added for me
# 323950 bills so far
# 11594 bills added for mi
# 335544 bills so far
# 28231 bills added for mn
# 363775 bills so far
# 9696 bills added for mo
# 373471 bills so far
# 29669 bills added for ms
# 403140 bills so far
# 3565 bills added for mt
# 406705 bills so far
# 9911 bills added for nc
# 416616 bills so far
# 2778 bills added for nd
# 419394 bills so far
# 5591 bills added for ne
# 424985 bills so far
# 5468 bills added for nh
# 430453 bills so far
# 40728 bills added for nj
# 471181 bills so far
# 8217 bills added for nm
# 479398 bills so far
# 4553 bills added for nv
# 483951 bills so far
# 91947 bills added for ny
# 575898 bills so far
# 4370 bills added for oh
# 580268 bills so far
# 13419 bills added for ok
# 593687 bills so far
# 8787 bills added for or
# 602474 bills so far
# 21291 bills added for pa
# 623765 bills so far
# 12087 bills added for ri
# 635852 bills so far
# 11697 bills added for sc
# 647549 bills so far
# 3984 bills added for sd
# 651533 bills so far
# 25999 bills added for tn
# 677532 bills so far
# 45356 bills added for tx
# 722888 bills so far
# 5119 bills added for ut
# 728007 bills so far
# 21122 bills added for va
# 749129 bills so far
# 4365 bills added for vt
# 753494 bills so far
# 11274 bills added for wa
# 764768 bills so far
# 7653 bills added for wi
# 772421 bills so far
# 13435 bills added for wv
# 785856 bills so far
# 2086 bills added for wy

# %%
#bill_titles = pd.read_csv('StateBills.csv', index_col=0)
# remove entries with no doc_id, since no text and cannot map to open_bill_id
bill_titles = bill_titles[bill_titles.doc_id!=" "]

doc_bill_map = pd.read_csv('doc_to_openbill_id.csv', index_col=0)
# keep only rows with bill title, drops excess open_bill_ids (otherwise no label/bill title)
bill_titles = pd.merge(left=bill_titles, right=doc_bill_map, on = 'doc_id', how='left')

print("bills with titles", len(bill_titles))
print("bills with text", len(bill_text))

# keep only rows with both bill title and bill text 
bills = pd.merge(left=bill_titles, right=bill_text, on = 'open_bill_id', how='inner')
print("bills with titles & text", len(bills))

all_bills = bills
# Out:
# bills with titles 814504
# bills with text 787942
# bills with titles & text 787842

# %%
len(bills[bills.guns])
# Out:
# 7220

# %%
def saveDescriptives(Y_cv, Y_predict): 
    # Number of positives for training and cv
    false_pos = sum([y1 == True and y1!=y2 for (y1,y2) in zip(Y_predict, Y_cv)])
    false_neg = sum([y1 == False and y1!=y2 for (y1,y2) in zip(Y_predict, Y_cv)])
    true_pos = sum([y1 == True and y1==y2 for (y1,y2) in zip(Y_predict, Y_cv)])
    true_neg = sum([y1 == False and y1==y2 for (y1,y2) in zip(Y_predict, Y_cv)])
    precision = true_pos/(true_pos + false_pos)
    recall = true_pos/(true_pos + false_neg)
        
    print("-performance-")
    print("true positives:", true_pos, "false positives:", false_pos, "true negatives:", true_neg, "false negatives:", false_neg)
    row = [true_pos, false_pos, true_neg, false_neg, precision, recall]
    return(row)

# %%
def take_out_random_sample(df, size):
    subset = df.sample(size)
    sample = df.ix[subset.index]
    return (df.drop(subset.index), sample)

# %%
def tokenizer(bill_text):
    tokens = []
    for bill in bill_text:
        words = bill.split()
        word_list = [word.lower() for word in words]
        token_list = [porter.stem(word) for word in word_list not in stoplist]
        tokens.append(token_list)
    return(tokens)

# %%
bills = all_bills

# %%
colnames = ["issue", "model", "TP", "FP", "TN", "FN", "precision", "recall"]
t3 = pd.DataFrame(columns = colnames)

# Split into training and test data
rs = ShuffleSplit(n_splits=1, test_size=.30, random_state=20170201)
indices = rs.split(all_bills)
for train_index, test_index in indices:
    training = all_bills.iloc[train_index]
    test_set = all_bills.iloc[test_index]

print("Training:", len(training), "Test:", len(test_set))

# For issue of guns, tune labels
issue = 'guns'

# TESTING THE GUN ISSUE - RECREATE THE LABELS TO REMOVE SOME STRAY ITEMS 
newlabel = ((bills.title.str.lower().str.contains('firearm')) |
      (bills.title.str.lower().str.contains(r'\bguns?\b')) |
      (bills.title.str.lower().str.contains('ammunition')) |
      (bills.title.str.lower().str.contains('rifle')) |
      (bills.title.str.lower().str.contains('shotgun')) |
      (bills.title.str.lower().str.contains('concealed')) |
      (bills.subjects_all.str.lower().str.contains('firearms')) |
      (bills.subjects_all.str.lower().str.contains('weapons')) |
      (bills.title.str.lower().str.contains('handgun')))

training['label'] = newlabel    

print("%s issue bills" % sum(training['label']==True))
print("%s total bills" % len(training['label']))

# First save test data with original composition
new_index = rs.split(training)
for train_set, cv_set in new_index:
    X_train = training.iloc[train_set]
    cv = training.iloc[cv_set]

# Create training data with adjusted proportion
t_yes = X_train[X_train['label']==True]
t_no = X_train[X_train['label']==False] 

print("Training True", len(t_yes))
print("Training False", len(t_no))

size = 3000
prop = 0.10
t = t_yes.sample(size*prop) 
t = t.append(t_no.sample(size*(1-prop)))

Y_train = t['label'].tolist()
Y_test = cv['label'].tolist()
               
print("%s in train set" % len(Y_train))
print("%s in cv set" % len(Y_test))

# Tokenize and transform
vectorizer = CountVectorizer(min_df=10)    
transformer = TfidfTransformer(norm='l2')    

tokenize = Pipeline([
    ('vectorizer', vectorizer),
    ('transformer', transformer)
])

X_train = tokenize.fit_transform(t['bill_text'].tolist())

print("Fitting Logistic Regression")
classy_log = LogisticRegression().fit(X_train, Y_train)
#classy_svc = LinearSVC().fit(X_train, Y_train)
#classy_gnb = GaussianNB().fit(X_train.toarray(), y_train)
# commented this out to just simplify things and avoid the parameter search
# but probably time now to bring it back in

cross_val = StratifiedShuffleSplit(n_splits=5, test_size=0.2, random_state=0)

print("Grid Search for Logistic:")
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000] }
grid_log = GridSearchCV(LogisticRegression(), param_grid, cv=None)
grid_log.fit(X_train, Y_train)
log_param = grid_log.best_params_
classy_log = LogisticRegression(C = log_param['C']).fit(X_train, Y_train)
print("The best parameters are %s with a score of %0.2f \n"
  % (grid_log.best_params_, grid_log.best_score_))

print("Grid Search for SVM - Gaussian:")
C_range = np.logspace(-2, 10, 5)
gamma_range = np.logspace(-9, 3, 5)
param_grid = dict(gamma=gamma_range, C=C_range)
cross_val = StratifiedShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
grid_svm = GridSearchCV(SVC(), param_grid=param_grid, cv=None)
grid_svm.fit(X_train, Y_train)
svm_param = grid_svm.best_params_
print("The best parameters are %s with a score of %0.2f \n"
  % (grid_svm.best_params_, grid_svm.best_score_))
classy_svm = SVC(gamma=svm_param['gamma'], C = svm_param['C']).fit(X_train, Y_train)

print("Predicting on test set")
X_tokens = tokenize.transform(cv['bill_text'].tolist())
Y_pred_svm = classy_svm.predict(X_tokens)
Y_score = classy_svm.decision_function(X_tokens)
Y_pred_log = classy_log.predict(X_tokens)
Y_prob = classy_log.predict_proba(X_tokens)

perform_log = saveDescriptives(Y_test, Y_pred_log)
perform_svm = saveDescriptives(Y_test, Y_pred_svm)

m1 = pd.DataFrame([issue, "Logistic"] + perform_log, index = colnames).transpose()
m2 = pd.DataFrame([issue, "SVC (gaussian)"] + perform_svm, index = colnames).transpose()

t3 = t3.append(m1)
t3 = t3.append(m2)
# Out:
# Training: 220595 Test: 94542
# /Users/kelly/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 525 issue bills
# 220595 total bills
# Training True 361
# Training False 30600
# 3000 in train set
# 66179 in cv set
# Fitting Logistic Regression
# Grid Search for Logistic:
# The best parameters are {'C': 1000} with a score of 0.97
#
# Grid Search for SVM - Gaussian:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-196-635f741d896b> in <module>()
#      89 cross_val = StratifiedShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
#      90 grid_svm = GridSearchCV(SVC(), param_grid=param_grid, cv=None)
# ---> 91 grid_svm.fit(X_train, Y_train)
#      92 svm_param = grid_svm.best_params_
#      93 print("The best parameters are %s with a score of %0.2f \n"
#
# /Users/kelly/anaconda/lib/python3.5/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups)
#     943             train/test set.
#     944         """
# --> 945         return self._fit(X, y, groups, ParameterGrid(self.param_grid))
#     946
#     947
#
# /Users/kelly/anaconda/lib/python3.5/site-packages/sklearn/model_selection/_search.py in _fit(self, X, y, groups, parameter_iterable)
#     562                                   return_times=True, return_parameters=True,
#     563                                   error_score=self.error_score)
# --> 564           for parameters in parameter_iterable
#     565           for train, test in cv_iter)
#     566
#
# /Users/kelly/anaconda/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     756             # was dispatched. In particular this covers the edge
#     757             # case of Parallel used with an exhausted iterator.
# --> 758             while self.dispatch_one_batch(iterator):
#     759                 self._iterating = True
#     760             else:
#
# /Users/kelly/anaconda/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     606                 return False
#     607             else:
# --> 608                 self._dispatch(tasks)
#     609                 return True
#     610
#
# /Users/kelly/anaconda/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     569         dispatch_timestamp = time.time()
#     570         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 571         job = self._backend.apply_async(batch, callback=cb)
#     572         self._jobs.append(job)
#     573
#
# /Users/kelly/anaconda/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     107     def apply_async(self, func, callback=None):
#     108         """Schedule a func to be run"""
# --> 109         result = ImmediateResult(func)
#     110         if callback:
#     111             callback(result)
#
# /Users/kelly/anaconda/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     324         # Don't delay the application, to avoid keeping the input
#     325         # arguments in memory
# --> 326         self.results = batch()
#     327
#     328     def get(self):
#
# /Users/kelly/anaconda/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /Users/kelly/anaconda/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /Users/kelly/anaconda/lib/python3.5/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, error_score)
#     236             estimator.fit(X_train, **fit_params)
#     237         else:
# --> 238             estimator.fit(X_train, y_train, **fit_params)
#     239
#     240     except Exception as e:
#
# /Users/kelly/anaconda/lib/python3.5/site-packages/sklearn/svm/base.py in fit(self, X, y, sample_weight)
#     187
#     188         seed = rnd.randint(np.iinfo('i').max)
# --> 189         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     190         # see comment on the other call to np.iinfo in this file
#     191
#
# /Users/kelly/anaconda/lib/python3.5/site-packages/sklearn/svm/base.py in _sparse_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     276                 sample_weight, self.nu, self.cache_size, self.epsilon,
#     277                 int(self.shrinking), int(self.probability), self.max_iter,
# --> 278                 random_seed)
#     279
#     280         self._warn_from_fit_status()
#
# sklearn/svm/libsvm_sparse.pyx in sklearn.svm.libsvm_sparse.libsvm_sparse_train (sklearn/svm/libsvm_sparse.c:2784)()
#
# /Users/kelly/anaconda/lib/python3.5/site-packages/scipy/sparse/compressed.py in __init__(self, arg1, shape, dtype, copy)
#      22     """base matrix class for compressed row and column oriented matrices"""
#      23
# ---> 24     def __init__(self, arg1, shape=None, dtype=None, copy=False):
#      25         _data_matrix.__init__(self)
#      26
#
# KeyboardInterrupt:

# %%
for train_set, cv_set in new_index:
    X_train = training.loc[train_set,:]
    cv = training.loc[cv_set,:]
    
cv.head()
# Out:
#              doc_id            bill_name state  \
# 87364   FLD00031701        FL_2015_SB 76    FL
# 193252  ILD00084658                         IL
# 500714  NYD00149516  NY_2013-2014_A 5402    NY
# 259530  LAD00035583       LA_2014_HB 501    LA
# 197486  ILD00076243                         IL
#
#                                                     title  \
# 87364   RELIEF OF MELVIN AND ALMA COLINDRES BY THE CIT...
# 193252                          MEMORIAL - JEFFERY PORTER
# 500714  REQUIRES APPROVAL OF THE GOVERNING BODY OF A C...
# 259530  VOTING/REGISTRATION:Â Â PROVIDES FOR VOTER REG...
# 197486                             MEMORIAL-BRENT STAYTON
#
#                 subjects_all abortion education energy environment   guns  \
# 87364                     []    False     False  False       False  False
# 193252                    []    False     False  False       False  False
# 500714  ['GENERAL CITY LAW']    False     False  False       False  False
# 259530                    []    False     False  False       False  False
# 197486                    []    False     False  False       False  False
#
#        health transport unionlabor open_bill_id  \
# 87364   False     False      False  FLB00008908
# 193252  False     False      False  ILB00042641
# 500714  False     False      False  NYB00039492
# 259530  False     False      False  LAB00011196
# 197486  False     False      False  ILB00038114
#
#                                                 bill_text  label
# 87364   \n\r\n       Florida Senate - 2015            ...    NaN
# 193252  \n\n\n\n\n\n\n\n\nIllinois General Assembly - ...    NaN
# 500714  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\nNew York State A...  False
# 259530  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...    NaN
# 197486  \n\n\n\n\n\n\n\n\nIllinois General Assembly - ...    NaN

# %%
probs = Y_prob[:,1]
scores = Y_score
#print(log_probs.tolist())
features = vectorizer.get_feature_names()
log_coefs = classy_log.coef_
svm_coefs = classy_svm.coef_

# %%
coefs = pd.DataFrame({'features': features, 'log': log_coefs.tolist().pop(0), 'svc': svc_coefs.tolist().pop(0), 'svm': svm_coefs.tolist().pop(0)})
print("Top words in log model \n", coefs.sort_values('log')[0:40])
print()
print("Top words in svc model \n", coefs.sort_values('svc')[0:40])
print()
print("Top words in svm model \n", coefs.sort_values('svm')[0:40])
# Out:
#   features       log       svm
# 0       00  0.590199  0.532705
# 1      000 -0.536057 -0.108290
# 2    00000 -0.106719 -0.045798
# 3   000000 -0.009350 -0.006083
# 4   0000ff  0.122377  0.019946

# %%
# Create empty performance table 
colnames = ["issue", "model", "TP", "FP", "TN", "FN", "precision", "recall"]
t4 = pd.DataFrame(columns = colnames)

# Split into test and training set
rs = ShuffleSplit(n_splits=1, test_size=.30, random_state=20170201)
indices = rs.split(all_bills)
training = all_bills[indices.train[0]]
test = all_bills[indices.test[0]]




print("%s in train set" % len(Y_train))
print("%s in test set" % len(y_test))


print("Fitting word2vec and transforming")
model = gensim.models.Word2Vec(tokenizer(X_text), size=100, min_count = 10)
w2v = dict(zip(model.index2word, model.syn0))
X_train = TfidfEmbeddingVectorizer(w2v, Y_train).tolist()

model.save('/word2vec_model')
#model = gensim.models.Word2Vec.load('/word2vec_model')

print("Training set created, fitting models")

classy_svc = LinearSVC().fit(X_train, Y_train)
classy_log = LogisticRegression().fit(X_train, Y_train)
#classy_gnb = GaussianNB().fit(X_train.toarray(), y_train)
# commented this out to just simplify things and avoid the parameter search
# but probably time now to bring it back in

print("Performing grid search for SVM - gaussian")
C_range = np.logspace(-2, 10, 13)
gamma_range = np.logspace(-9, 3, 13)
param_grid = dict(gamma=gamma_range, C=C_range)
cross_val = StratifiedShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
grid = GridSearchCV(SVC(), param_grid=param_grid, cv=cross_val)
grid.fit(X_train, Y_train)
param = grid.best_params_
print("The best parameters are %s with a score of %0.2f"
  % (grid.best_params_, grid.best_score_))
classy_svm = SVC(gamma=param['gamma'], C = param['C']).fit(X_train, Y_train)

print("Models fit, creating test matrix")
X_test = tokenize.transform(test1['bill_text'].tolist())
Y_test = test1[issue].tolist()

print("Test matrix created, applying model\n")
Y_pred_svc = classy_svc.predict(X_test)
Y_pred_log = classy_log.predict(X_test)
Y_prob_log = classy_log.predict_proba(X_test)
#    Y2 = classy_svm.predict(X_cv)
Y_pred_svm = classy_svc.predict(X_test)

perform_svc = saveDescriptives(Y_test, Y_pred_svc)
perform_log = saveDescriptives(Y_test, Y_pred_log)
perform_svm = saveDescriptives(Y_test, Y_pred_svm)


m1 = pd.DataFrame([issue, "SVC (linear)"] + perform_svc, index = colnames).transpose()
m2 = pd.DataFrame([issue, "Logistic"] + perform_log, index = colnames).transpose()
m3 = pd.DataFrame([issue, "SVC (gaussian)"] + perform_svm, index = colnames).transpose()

t4 = t4.append(m1)
t4 = t4.append(m2)
t4 = t4.append(m3)
# Out:
# Top words in log model
#              features       log       svm
# 2573             and -1.556047 -0.352815
# 13755        whereas -1.511321 -0.215298
# 6466             for -1.362886 -0.587248
# 12787            the -0.966305  0.084370
# 7042          health -0.956036 -0.655205
# 3849           child -0.928619 -0.469921
# 11815        service -0.915945 -0.572366
# 12666            tax -0.912884 -0.315133
# 3643            care -0.909887 -0.239823
# 7683       insurance -0.807250 -0.446561
# 2551          amount -0.744199 -0.381786
# 7316        illinois -0.736186 -0.408727
# 5843          entity -0.670494 -0.624733
# 5487          driver -0.668700 -0.703406
# 11817       services -0.664105  0.073486
# 8906     mississippi -0.651836 -0.424797
# 4101    commissioner -0.647915 -0.596209
# 10457        program -0.643370 -0.083753
# 3326           board -0.632992 -0.057029
# 7870             its -0.622840 -0.183710
# 7021          hawaii -0.617230 -0.175241
# 7447          income -0.608919 -0.077591
# 10072           plan -0.606141 -0.119404
# 13933           year -0.600259 -0.234333
# 4456        contract -0.583064 -0.296906
# 11249       resolved -0.571139 -0.189025
# 3776              ch -0.551359 -0.529480
# 4129       community -0.540165 -0.283742
# 8760          member -0.537062 -0.355655
# 1                000 -0.536057 -0.108290
# 4126   communication -0.523128 -0.502615
# 6635           funds -0.522980 -0.217344
# 12689      technical -0.522849 -0.476997
# 13853           work -0.514850 -0.279291
# 7999    jurisdiction -0.511146 -0.747794
# 8416            loan -0.505265 -0.268147
# 7311            ilcs -0.504918 -0.458899
# 3225        benefits -0.503691 -0.117030
# 11246     resolution -0.502667 -0.033096
# 4158    compensation -0.502089 -0.255972
#
# Top words in svm model
#              features       log       svm
# 8114             ktg -0.262107 -0.830785
# 7999    jurisdiction -0.511146 -0.747794
# 10832       reckless -0.188768 -0.716936
# 5487          driver -0.668700 -0.703406
# 10410    proceedings -0.385371 -0.663066
# 7042          health -0.956036 -0.655205
# 5843          entity -0.670494 -0.624733
# 2192       acquiring -0.118116 -0.601569
# 4101    commissioner -0.647915 -0.596209
# 12939          title -0.342413 -0.591067
# 6466             for -1.362886 -0.587248
# 5223        disabled -0.349988 -0.573129
# 11815        service -0.915945 -0.572366
# 10549      protected -0.233617 -0.565911
# 492             1308 -0.185333 -0.555641
# 3776              ch -0.551359 -0.529480
# 12558   surveillance -0.129674 -0.527295
# 4896       defendant -0.229428 -0.518903
# 3642           cards -0.023274 -0.517330
# 5741             end -0.450689 -0.510127
# 3620         capital -0.414977 -0.508085
# 887             2016 -0.159152 -0.505860
# 10868      recording -0.390180 -0.503308
# 4126   communication -0.523128 -0.502615
# 10383         prison -0.107293 -0.483004
# 13762          which -0.400217 -0.482145
# 12689      technical -0.522849 -0.476997
# 915               21 -0.222895 -0.474624
# 12368          style -0.200080 -0.474270
# 12502       superior -0.148958 -0.472766
# 5814        enrolled -0.425888 -0.471559
# 3849           child -0.928619 -0.469921
# 1209              38 -0.132316 -0.466667
# 12876          those -0.258805 -0.459388
# 2448       alcoholic -0.356155 -0.459119
# 7311            ilcs -0.504918 -0.458899
# 9975         persons  0.045396 -0.457440
# 5491         driving -0.478356 -0.457292
# 13059        traffic -0.472336 -0.448865
# 5922    establishing -0.097558 -0.447784

# %%
len(training)
# Out:
# 220595

# %%
test1['probs'] = probs

# %%
## Examine the mistakes
# False positive
fp_titles = test1[Y_pred_log & ~test1.guns]['title'].tolist()
fp_probs = test1[Y_pred_log & ~test1.guns]['probs'].tolist()

fp = pd.DataFrame({'titles': fp_titles, 'probs': fp_probs})
fp
# Out:
#       probs                                             titles
# 0  0.818157  ESTABLISHES ARSON INVESTIGATION UNIT IN DIVISI...
# 1  0.968702  ENACTING THE KANSAS PROTECTION AGAINST TERRORI...
# 2  0.996321                          FOID&CRIM CD-PRIVATE&GANG
# 3  0.657883  REQUIRE BACKGROUND CHECKS AND OTHER REQUIREMEN...
# 4  0.750775                                  CRIMINAL LAW-TECH
# 5  0.720328                                  CRIMINAL LAW-TECH
# 6  0.629500                                CRIM CD-AGG BATTERY

# %%
#False negatives

fn_titles = test1[~Y_pred_svc & test1.guns]['title'].tolist()
fn_probs = test1[~Y_pred_svc & test1.guns]['probs'].tolist()

fn = pd.DataFrame({'titles': fn_titles, 'probs': fn_probs})
fn
# Out:
#        probs                                             titles
# 0   0.122024  AN ACT RELATIVE TO FIREARM SAFETY TRAINING OF ...
# 1   0.257156  ESTABLISHES THE MISSOURI FIREARMS INDUSTRY NON...
# 2   0.318399                           HOSP SECURITY CARRY GUNS
# 3   0.135527              UNSAFE HANDGUNS: SINGLE-SHOT PISTOLS.
# 4   0.120468  RELATING TO: MAKING A FALSE THREAT TO USE A FI...
# 5   0.089289  AN ACT TO ESTABLISH A NATIONAL RIFLE ASSOCIATI...
# 6   0.098093                          DPH-FIREARM INJURIES-TECH
# 7   0.075485  AUXILIARY POLICE OFFICERS; FIREARMS TRAINING S...
# 8   0.096181                   WEAPONS ON PUBLIC TRANSPORTATION
# 9   0.118181  RELATES TO THE MINIMUM DISTANCE A FIREARM MAY ...
# 10  0.110857  RELATES TO POSSESSION AND SALE OF ARMOR PIERCI...
# 11  0.214819  BALTIMORE CITY SCHOOL POLICE FORCE - CARRYING ...
# 12  0.068080  CONSTITUTIONAL AMENDMENT TO PROVIDE THAT THE R...
# 13  0.136406  PROVIDES THAT COLLATERAL LOAN BROKERS SHALL ST...
# 14  0.154180  ESTABLISHES CERTAIN CRIMES RELATING TO THE CRI...
# 15  0.099515          REGULATING CERTAIN SPORT SHOOTING RANGES.
# 16  0.241393  WEAPONS - AS ENACTED, MAKES LAWFUL THE SALE, T...
# 17  0.049959  HANDGUN PERMITS - AS INTRODUCED, CHANGES THE A...

# %%
################################### OLD TRAINING/TESTING CODE #####################################

# %%
### Split into test, cv, and training ###
# Keep only union of both datasets (i.e. no bill titles without bill text, and no bill text without title/labels)

random.seed(20170106)

df = bills
print("Labeled Bills:",len(df))
nprop = round(len(df)*0.20)

subset1 = df.sample(nprop)
test = df.ix[subset1.index]
df = df.drop(subset1.index)

subset2 = df.sample(nprop)
cv = df.ix[subset2.index]
df = df.drop(subset2.index)

training = df

print("Test Set:", len(test), "CV Set:", len(cv), "Training Set:", len(df))
### Check data
#print(training.sort_values('doc_id').head()) 
#print(test.sort_values('doc_id').head())
#print(cv.sort_values('doc_id').head())
# Out:
# Labeled Bills: 787842
# Test Set: 157568 CV Set: 157568 Training Set: 472706

# %%
### Training Classifiers ###

#training_selected = training[(training.state=='NM')|(training.state=='OH')|(training.state=='MS')|(training.state=='OK')|(training.state=='VA')]
#cv_selected = cv[(cv.state=='NM')|(cv.state=='OH')|(cv.state=='MS')|(cv.state=='OK')|(cv.state=='VA')]
#print(len(training_selected), len(cv_selected))

# abortion true: 1062 
# Training set size
size = 5000

# List of issues
issues = ['abortion', 'education', 'energy', 'environment', 'guns', 'health', 'transport', 'unionlabor']

# Table storing model descriptives
colnames = ["issue", "prop", "cv-error", "model", "TP", "FP", "TN", "FN"]

props = [0.05, 0.10, 0.15, 0.20]

issueList = []

for issue in issues:

    t3 = pd.DataFrame(columns = colnames)
    
    C_list = []
    gamma_list = []
    
    for prop in props:
        print(issue,":", prop)
        
        # Subset training data
        t_yes = training[training[issue]==True]
        t_no = training[training[issue]==False] 
        
        print("TRUE", len(t_yes))
        print("FALSE", len(t_no))

        t = t_yes.sample(size*prop) 
        t = t.append(t_no.sample(size*(1-prop)))

        y_train = t[issue].tolist()
        full_text = t['bill_text'].tolist()

        vectorizer = CountVectorizer(min_df=10, stop_words = stoplist)
        transformer = TfidfTransformer(norm='l1')    

        tokenize = Pipeline([
            ('vectorizer', vectorizer),
            ('transformer', transformer)
        ])

        X_train = tokenize.fit_transform(full_text)

        subset = t.sample(1000)
        X_tokens = subset['bill_text']
        X = tokenize.transform(X_tokens)
        y = subset[issue].tolist()

        C_range = np.logspace(-2, 10, 13)
        gamma_range = np.logspace(-9, 3, 13)
        param_grid = dict(gamma=gamma_range, C=C_range)
        cross_val = StratifiedShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
        grid = GridSearchCV(SVC(), param_grid=param_grid, cv=cross_val)
        grid.fit(X, y)
        param = grid.best_params_
        print("The best parameters are %s with a score of %0.2f"
          % (grid.best_params_, grid.best_score_))
        
        issue_C = param['C']
        C_list.append(issue_C)
        issue_gamma = param['gamma']
        gamma_list.append(issue_gamma)
        
        # Tokenize cross-validation data 
        # Set cv size 
        c = cv.sample(size)
        y_cv = c[issue].tolist()
        cv_text = c['bill_text'].tolist()
        X_cv = tokenize.transform(cv_text)

        # Fit models on training
        classy_svc = LinearSVC().fit(X_train, y_train)
        classy_log = LogisticRegression().fit(X_train, y_train)
        classy_gnb = GaussianNB().fit(X_train.toarray(), y_train)
        classy_svm = SVC(gamma=issue_gamma, C = issue_C).fit(X_train, y_train)

        # Predict on cross-validation
        Y1 = classy_svc.predict(X_cv)
        e1 = (Y1!=y_cv).sum()/len(y_cv)

        Y2 = classy_svm.predict(X_cv)
        e2 = (Y2!=y_cv).sum()/len(y_cv)

        Y3 = classy_log.predict(X_cv)
        #p3 = classy_log.predict_proba(X_cv)
        e3 = (Y3!=y_cv).sum()/len(y_cv)

        Y4 = classy_gnb.predict(X_cv.toarray())
        #p4 = classy_gnb.predict_proba(X_cv.toarray())
        e4 = (Y4!=y_cv).sum()/len(y_cv)

        # Number of positives for training and cv
        print("TRAINING SIZE", size)
        print("TRAINING TRUE:", sum(y_train), "CV TRUE:", sum(y_cv))
        print("M1: SVC (LINEAR) ERROR", e1)
        perform1 = saveDescriptives(y_cv, Y1)
        print("M2: SVC (GAUSSIAN) ERROR", e2)
        perform2 = saveDescriptives(y_cv, Y2)
        print("M3: LOGISTIC ERROR", e3)
        perform3 = saveDescriptives(y_cv, Y3)
        print("M4: NAIVE BAYES ERROR", e4)
        perform4 = saveDescriptives(y_cv, Y4)

        m1 = pd.DataFrame([issue, prop, e1, "SVC (linear)"] + perform1, index = colnames).transpose()
        m2 = pd.DataFrame([issue, prop, e2, "SVC (rbf)"] + perform2, index = colnames).transpose()
        m3 = pd.DataFrame([issue, prop, e3, "Logistic"] + perform3, index = colnames).transpose()
        m4 = pd.DataFrame([issue, prop, e4, "NaiveBayes"] + perform4, index = colnames).transpose()

        t3 = t3.append(m1)
        t3 = t3.append(m2)
        t3 = t3.append(m3)
        t3 = t3.append(m4)

    issueList.append(t3)
# Out:
# abortion : 0.05
# TRUE 1092
# FALSE 471614
# The best parameters are {'C': 100.0, 'gamma': 1.0} with a score of 0.99
# TRAINING SIZE 5000
# TRAINING TRUE: 250 CV TRUE: 11
# M1: SVC (LINEAR) ERROR 0.002
# -performance-
# true positives: 1 false positives: 0 true negatives: 4989 false negatives: 10
# M2: SVC (GAUSSIAN) ERROR 0.0026
# -performance-
# true positives: 10 false positives: 12 true negatives: 4977 false negatives: 1
# M3: LOGISTIC ERROR 0.0022
# -performance-
# true positives: 0 false positives: 0 true negatives: 4989 false negatives: 11
# M4: NAIVE BAYES ERROR 0.0106
# -performance-
# true positives: 7 false positives: 49 true negatives: 4940 false negatives: 4
# abortion : 0.1
# TRUE 1092
# FALSE 471614
# The best parameters are {'C': 1000.0, 'gamma': 0.10000000000000001} with a score of 0.97
# TRAINING SIZE 5000
# TRAINING TRUE: 500 CV TRUE: 8
# M1: SVC (LINEAR) ERROR 0.0006
# -performance-
# true positives: 5 false positives: 0 true negatives: 4992 false negatives: 3
# M2: SVC (GAUSSIAN) ERROR 0.001
# -performance-
# true positives: 8 false positives: 5 true negatives: 4987 false negatives: 0
# M3: LOGISTIC ERROR 0.0016
# -performance-
# true positives: 0 false positives: 0 true negatives: 4992 false negatives: 8
# M4: NAIVE BAYES ERROR 0.015
# -performance-
# true positives: 6 false positives: 73 true negatives: 4919 false negatives: 2
# abortion : 0.15
# TRUE 1092
# FALSE 471614
# The best parameters are {'C': 100.0, 'gamma': 1.0} with a score of 0.98
# TRAINING SIZE 5000
# TRAINING TRUE: 750 CV TRUE: 12
# M1: SVC (LINEAR) ERROR 0.001
# -performance-
# true positives: 8 false positives: 1 true negatives: 4987 false negatives: 4
# M2: SVC (GAUSSIAN) ERROR 0.0032
# -performance-
# true positives: 11 false positives: 15 true negatives: 4973 false negatives: 1
# M3: LOGISTIC ERROR 0.0024
# -performance-
# true positives: 0 false positives: 0 true negatives: 4988 false negatives: 12
# M4: NAIVE BAYES ERROR 0.0204
# -performance-
# true positives: 10 false positives: 100 true negatives: 4888 false negatives: 2
# abortion : 0.2
# TRUE 1092
# FALSE 471614
# The best parameters are {'C': 1000.0, 'gamma': 10.0} with a score of 0.96
# TRAINING SIZE 5000
# TRAINING TRUE: 1000 CV TRUE: 9
# M1: SVC (LINEAR) ERROR 0.001
# -performance-
# true positives: 6 false positives: 2 true negatives: 4989 false negatives: 3
# M2: SVC (GAUSSIAN) ERROR 0.009
# -performance-
# true positives: 9 false positives: 45 true negatives: 4946 false negatives: 0
# M3: LOGISTIC ERROR 0.0018
# -performance-
# true positives: 0 false positives: 0 true negatives: 4991 false negatives: 9
# M4: NAIVE BAYES ERROR 0.0266
# -performance-
# true positives: 5 false positives: 129 true negatives: 4862 false negatives: 4
# education : 0.05
# TRUE 34200
# FALSE 438506
# The best parameters are {'C': 100.0, 'gamma': 10.0} with a score of 0.96
# TRAINING SIZE 5000
# TRAINING TRUE: 250 CV TRUE: 386
# M1: SVC (LINEAR) ERROR 0.0772
# -performance-
# true positives: 0 false positives: 0 true negatives: 4614 false negatives: 386
# M2: SVC (GAUSSIAN) ERROR 0.0628
# -performance-
# true positives: 144 false positives: 72 true negatives: 4542 false negatives: 242
# M3: LOGISTIC ERROR 0.0772
# -performance-
# true positives: 0 false positives: 0 true negatives: 4614 false negatives: 386
# M4: NAIVE BAYES ERROR 0.102
# -performance-
# true positives: 29 false positives: 153 true negatives: 4461 false negatives: 357
# education : 0.1
# TRUE 34200
# FALSE 438506
# The best parameters are {'C': 10.0, 'gamma': 10.0} with a score of 0.92
# TRAINING SIZE 5000
# TRAINING TRUE: 500 CV TRUE: 363
# M1: SVC (LINEAR) ERROR 0.0718
# -performance-
# true positives: 6 false positives: 2 true negatives: 4635 false negatives: 357
# M2: SVC (GAUSSIAN) ERROR 0.0528
# -performance-
# true positives: 178 false positives: 79 true negatives: 4558 false negatives: 185
# M3: LOGISTIC ERROR 0.0726
# -performance-
# true positives: 0 false positives: 0 true negatives: 4637 false negatives: 363
# M4: NAIVE BAYES ERROR 0.11
# -performance-
# true positives: 47 false positives: 234 true negatives: 4403 false negatives: 316
# education : 0.15
# TRUE 34200
# FALSE 438506
# The best parameters are {'C': 100000.0, 'gamma': 0.001} with a score of 0.92
# TRAINING SIZE 5000
# TRAINING TRUE: 750 CV TRUE: 354
# M1: SVC (LINEAR) ERROR 0.0674
# -performance-
# true positives: 36 false positives: 19 true negatives: 4627 false negatives: 318
# M2: SVC (GAUSSIAN) ERROR 0.0526
# -performance-
# true positives: 220 false positives: 129 true negatives: 4517 false negatives: 134
# M3: LOGISTIC ERROR 0.0708
# -performance-
# true positives: 0 false positives: 0 true negatives: 4646 false negatives: 354
# M4: NAIVE BAYES ERROR 0.1276
# -performance-
# true positives: 84 false positives: 368 true negatives: 4278 false negatives: 270
# education : 0.2
# TRUE 34200
# FALSE 438506
# The best parameters are {'C': 100.0, 'gamma': 10.0} with a score of 0.90
# TRAINING SIZE 5000
# TRAINING TRUE: 1000 CV TRUE: 386
# M1: SVC (LINEAR) ERROR 0.07
# -performance-
# true positives: 82 false positives: 46 true negatives: 4568 false negatives: 304
# M2: SVC (GAUSSIAN) ERROR 0.0762
# -performance-
# true positives: 256 false positives: 251 true negatives: 4363 false negatives: 130
# M3: LOGISTIC ERROR 0.0772
# -performance-
# true positives: 0 false positives: 0 true negatives: 4614 false negatives: 386
# M4: NAIVE BAYES ERROR 0.1524
# -performance-
# true positives: 96 false positives: 472 true negatives: 4142 false negatives: 290
# energy : 0.05
# TRUE 14727
# FALSE 457979
# The best parameters are {'C': 1000.0, 'gamma': 1.0} with a score of 0.97
# TRAINING SIZE 5000
# TRAINING TRUE: 250 CV TRUE: 175
# M1: SVC (LINEAR) ERROR 0.035
# -performance-
# true positives: 0 false positives: 0 true negatives: 4825 false negatives: 175
# M2: SVC (GAUSSIAN) ERROR 0.0258
# -performance-
# true positives: 85 false positives: 39 true negatives: 4786 false negatives: 90
# M3: LOGISTIC ERROR 0.035
# -performance-
# true positives: 0 false positives: 0 true negatives: 4825 false negatives: 175
# M4: NAIVE BAYES ERROR 0.0514
# -performance-
# true positives: 10 false positives: 92 true negatives: 4733 false negatives: 165
# energy : 0.1
# TRUE 14727
# FALSE 457979
# The best parameters are {'C': 100.0, 'gamma': 1.0} with a score of 0.94
# TRAINING SIZE 5000
# TRAINING TRUE: 500 CV TRUE: 163
# M1: SVC (LINEAR) ERROR 0.0322
# -performance-
# true positives: 3 false positives: 1 true negatives: 4836 false negatives: 160
# M2: SVC (GAUSSIAN) ERROR 0.0258
# -performance-
# true positives: 82 false positives: 48 true negatives: 4789 false negatives: 81
# M3: LOGISTIC ERROR 0.0326
# -performance-
# true positives: 0 false positives: 0 true negatives: 4837 false negatives: 163
# M4: NAIVE BAYES ERROR 0.0748
# -performance-
# true positives: 27 false positives: 238 true negatives: 4599 false negatives: 136
# energy : 0.15
# TRUE 14727
# FALSE 457979
# The best parameters are {'C': 100000.0, 'gamma': 0.10000000000000001} with a score of 0.91
# TRAINING SIZE 5000
# TRAINING TRUE: 750 CV TRUE: 171
# M1: SVC (LINEAR) ERROR 0.0322
# -performance-
# true positives: 13 false positives: 3 true negatives: 4826 false negatives: 158
# M2: SVC (GAUSSIAN) ERROR 0.0556
# -performance-
# true positives: 113 false positives: 220 true negatives: 4609 false negatives: 58
# M3: LOGISTIC ERROR 0.0342
# -performance-
# true positives: 0 false positives: 0 true negatives: 4829 false negatives: 171
# M4: NAIVE BAYES ERROR 0.1094
# -performance-
# true positives: 46 false positives: 422 true negatives: 4407 false negatives: 125
# energy : 0.2
# TRUE 14727
# FALSE 457979
# The best parameters are {'C': 100.0, 'gamma': 10.0} with a score of 0.88
# TRAINING SIZE 5000
# TRAINING TRUE: 1000 CV TRUE: 161
# M1: SVC (LINEAR) ERROR 0.028
# -performance-
# true positives: 25 false positives: 4 true negatives: 4835 false negatives: 136
# M2: SVC (GAUSSIAN) ERROR 0.049
# -performance-
# true positives: 111 false positives: 195 true negatives: 4644 false negatives: 50
# M3: LOGISTIC ERROR 0.0322
# -performance-
# true positives: 0 false positives: 0 true negatives: 4839 false negatives: 161
# M4: NAIVE BAYES ERROR 0.133
# -performance-
# true positives: 66 false positives: 570 true negatives: 4269 false negatives: 95
# environment : 0.05
# TRUE 8073
# FALSE 464633
# The best parameters are {'C': 1000.0, 'gamma': 1.0} with a score of 0.96
# TRAINING SIZE 5000
# TRAINING TRUE: 250 CV TRUE: 86
# M1: SVC (LINEAR) ERROR 0.0172
# -performance-
# true positives: 0 false positives: 0 true negatives: 4914 false negatives: 86
# M2: SVC (GAUSSIAN) ERROR 0.0182
# -performance-
# true positives: 40 false positives: 45 true negatives: 4869 false negatives: 46
# M3: LOGISTIC ERROR 0.0172
# -performance-
# true positives: 0 false positives: 0 true negatives: 4914 false negatives: 86
# M4: NAIVE BAYES ERROR 0.0394
# -performance-
# true positives: 8 false positives: 119 true negatives: 4795 false negatives: 78
# environment : 0.1
# TRUE 8073
# FALSE 464633
# The best parameters are {'C': 1000.0, 'gamma': 1.0} with a score of 0.93
# TRAINING SIZE 5000
# TRAINING TRUE: 500 CV TRUE: 88
# M1: SVC (LINEAR) ERROR 0.0174
# -performance-
# true positives: 1 false positives: 0 true negatives: 4912 false negatives: 87
# M2: SVC (GAUSSIAN) ERROR 0.0304
# -performance-
# true positives: 59 false positives: 123 true negatives: 4789 false negatives: 29
# M3: LOGISTIC ERROR 0.0176
# -performance-
# true positives: 0 false positives: 0 true negatives: 4912 false negatives: 88
# M4: NAIVE BAYES ERROR 0.0682
# -performance-
# true positives: 13 false positives: 266 true negatives: 4646 false negatives: 75
# environment : 0.15
# TRUE 8073
# FALSE 464633
# The best parameters are {'C': 100.0, 'gamma': 1.0} with a score of 0.91
# TRAINING SIZE 5000
# TRAINING TRUE: 750 CV TRUE: 90
# M1: SVC (LINEAR) ERROR 0.0182
# -performance-
# true positives: 2 false positives: 3 true negatives: 4907 false negatives: 88
# M2: SVC (GAUSSIAN) ERROR 0.0258
# -performance-
# true positives: 58 false positives: 97 true negatives: 4813 false negatives: 32
# M3: LOGISTIC ERROR 0.018
# -performance-
# true positives: 0 false positives: 0 true negatives: 4910 false negatives: 90
# M4: NAIVE BAYES ERROR 0.0918
# -performance-
# true positives: 23 false positives: 392 true negatives: 4518 false negatives: 67
# environment : 0.2
# TRUE 8073
# FALSE 464633
# The best parameters are {'C': 10.0, 'gamma': 10.0} with a score of 0.89
# TRAINING SIZE 5000
# TRAINING TRUE: 1000 CV TRUE: 81
# M1: SVC (LINEAR) ERROR 0.016
# -performance-
# true positives: 9 false positives: 8 true negatives: 4911 false negatives: 72
# M2: SVC (GAUSSIAN) ERROR 0.0302
# -performance-
# true positives: 54 false positives: 124 true negatives: 4795 false negatives: 27
# M3: LOGISTIC ERROR 0.0162
# -performance-
# true positives: 0 false positives: 0 true negatives: 4919 false negatives: 81
# M4: NAIVE BAYES ERROR 0.1086
# -performance-
# true positives: 39 false positives: 501 true negatives: 4418 false negatives: 42
# guns : 0.05
# TRUE 4280
# FALSE 468426
# The best parameters are {'C': 1000.0, 'gamma': 1.0} with a score of 0.97
# TRAINING SIZE 5000
# TRAINING TRUE: 250 CV TRUE: 42
# M1: SVC (LINEAR) ERROR 0.008
# -performance-
# true positives: 3 false positives: 1 true negatives: 4957 false negatives: 39
# M2: SVC (GAUSSIAN) ERROR 0.0088
# -performance-
# true positives: 30 false positives: 32 true negatives: 4926 false negatives: 12
# M3: LOGISTIC ERROR 0.0084
# -performance-
# true positives: 0 false positives: 0 true negatives: 4958 false negatives: 42
# M4: NAIVE BAYES ERROR 0.0252
# -performance-
# true positives: 5 false positives: 89 true negatives: 4869 false negatives: 37
# guns : 0.1
# TRUE 4280
# FALSE 468426
# The best parameters are {'C': 1000.0, 'gamma': 1.0} with a score of 0.96
# TRAINING SIZE 5000
# TRAINING TRUE: 500 CV TRUE: 43
# M1: SVC (LINEAR) ERROR 0.0072
# -performance-
# true positives: 7 false positives: 0 true negatives: 4957 false negatives: 36
# M2: SVC (GAUSSIAN) ERROR 0.0074
# -performance-
# true positives: 37 false positives: 31 true negatives: 4926 false negatives: 6
# M3: LOGISTIC ERROR 0.0086
# -performance-
# true positives: 0 false positives: 0 true negatives: 4957 false negatives: 43
# M4: NAIVE BAYES ERROR 0.0366
# -performance-
# true positives: 15 false positives: 155 true negatives: 4802 false negatives: 28
# guns : 0.15
# TRUE 4280
# FALSE 468426
# The best parameters are {'C': 1000.0, 'gamma': 1.0} with a score of 0.95
# TRAINING SIZE 5000
# TRAINING TRUE: 750 CV TRUE: 39
# M1: SVC (LINEAR) ERROR 0.0072
# -performance-
# true positives: 8 false positives: 5 true negatives: 4956 false negatives: 31
# M2: SVC (GAUSSIAN) ERROR 0.0108
# -performance-
# true positives: 32 false positives: 47 true negatives: 4914 false negatives: 7
# M3: LOGISTIC ERROR 0.0078
# -performance-
# true positives: 0 false positives: 0 true negatives: 4961 false negatives: 39
# M4: NAIVE BAYES ERROR 0.0472
# -performance-
# true positives: 12 false positives: 209 true negatives: 4752 false negatives: 27
# guns : 0.2
# TRUE 4280
# FALSE 468426
# The best parameters are {'C': 1000.0, 'gamma': 0.10000000000000001} with a score of 0.95
# TRAINING SIZE 5000
# TRAINING TRUE: 1000 CV TRUE: 45
# M1: SVC (LINEAR) ERROR 0.0056
# -performance-
# true positives: 25 false positives: 8 true negatives: 4947 false negatives: 20
# M2: SVC (GAUSSIAN) ERROR 0.0086
# -performance-
# true positives: 40 false positives: 38 true negatives: 4917 false negatives: 5
# M3: LOGISTIC ERROR 0.009
# -performance-
# true positives: 0 false positives: 0 true negatives: 4955 false negatives: 45
# M4: NAIVE BAYES ERROR 0.0656
# -performance-
# true positives: 32 false positives: 315 true negatives: 4640 false negatives: 13
# health : 0.05
# TRUE 46168
# FALSE 426538
# The best parameters are {'C': 100.0, 'gamma': 100.0} with a score of 0.95
# TRAINING SIZE 5000
# TRAINING TRUE: 250 CV TRUE: 492
# M1: SVC (LINEAR) ERROR 0.0984
# -performance-
# true positives: 0 false positives: 0 true negatives: 4508 false negatives: 492
# M2: SVC (GAUSSIAN) ERROR 0.082
# -performance-
# true positives: 115 false positives: 33 true negatives: 4475 false negatives: 377
# M3: LOGISTIC ERROR 0.0984
# -performance-
# true positives: 0 false positives: 0 true negatives: 4508 false negatives: 492
# M4: NAIVE BAYES ERROR 0.1232
# -performance-
# true positives: 21 false positives: 145 true negatives: 4363 false negatives: 471
# health : 0.1
# TRUE 46168
# FALSE 426538
# The best parameters are {'C': 1000000.0, 'gamma': 0.0001} with a score of 0.93
# TRAINING SIZE 5000
# TRAINING TRUE: 500 CV TRUE: 480
# M1: SVC (LINEAR) ERROR 0.0946
# -performance-
# true positives: 7 false positives: 0 true negatives: 4520 false negatives: 473
# M2: SVC (GAUSSIAN) ERROR 0.0676
# -performance-
# true positives: 221 false positives: 79 true negatives: 4441 false negatives: 259
# M3: LOGISTIC ERROR 0.096
# -performance-
# true positives: 0 false positives: 0 true negatives: 4520 false negatives: 480
# M4: NAIVE BAYES ERROR 0.1336
# -performance-
# true positives: 68 false positives: 256 true negatives: 4264 false negatives: 412
# health : 0.15
# TRUE 46168
# FALSE 426538
# The best parameters are {'C': 10000.0, 'gamma': 1.0} with a score of 0.91
# TRAINING SIZE 5000
# TRAINING TRUE: 750 CV TRUE: 474
# M1: SVC (LINEAR) ERROR 0.0896
# -performance-
# true positives: 30 false positives: 4 true negatives: 4522 false negatives: 444
# M2: SVC (GAUSSIAN) ERROR 0.085
# -performance-
# true positives: 271 false positives: 222 true negatives: 4304 false negatives: 203
# M3: LOGISTIC ERROR 0.0948
# -performance-
# true positives: 0 false positives: 0 true negatives: 4526 false negatives: 474
# M4: NAIVE BAYES ERROR 0.1548
# -performance-
# true positives: 120 false positives: 420 true negatives: 4106 false negatives: 354
# health : 0.2
# TRUE 46168
# FALSE 426538
# The best parameters are {'C': 1000.0, 'gamma': 0.10000000000000001} with a score of 0.86
# TRAINING SIZE 5000
# TRAINING TRUE: 1000 CV TRUE: 515
# M1: SVC (LINEAR) ERROR 0.0884
# -performance-
# true positives: 89 false positives: 16 true negatives: 4469 false negatives: 426
# M2: SVC (GAUSSIAN) ERROR 0.064
# -performance-
# true positives: 335 false positives: 140 true negatives: 4345 false negatives: 180
# M3: LOGISTIC ERROR 0.103
# -performance-
# true positives: 0 false positives: 0 true negatives: 4485 false negatives: 515
# M4: NAIVE BAYES ERROR 0.1774
# -performance-
# true positives: 177 false positives: 549 true negatives: 3936 false negatives: 338
# transport : 0.05
# TRUE 27013
# FALSE 445693
# The best parameters are {'C': 10.0, 'gamma': 100.0} with a score of 0.96
# TRAINING SIZE 5000
# TRAINING TRUE: 250 CV TRUE: 292
# M1: SVC (LINEAR) ERROR 0.0584
# -performance-
# true positives: 0 false positives: 0 true negatives: 4708 false negatives: 292
# M2: SVC (GAUSSIAN) ERROR 0.0506
# -performance-
# true positives: 74 false positives: 35 true negatives: 4673 false negatives: 218
# M3: LOGISTIC ERROR 0.0584
# -performance-
# true positives: 0 false positives: 0 true negatives: 4708 false negatives: 292
# M4: NAIVE BAYES ERROR 0.078
# -performance-
# true positives: 13 false positives: 111 true negatives: 4597 false negatives: 279
# transport : 0.1
# TRUE 27013
# FALSE 445693
# The best parameters are {'C': 1000000.0, 'gamma': 0.0001} with a score of 0.94
# TRAINING SIZE 5000
# TRAINING TRUE: 500 CV TRUE: 299
# M1: SVC (LINEAR) ERROR 0.0568
# -performance-
# true positives: 18 false positives: 3 true negatives: 4698 false negatives: 281
# M2: SVC (GAUSSIAN) ERROR 0.0438
# -performance-
# true positives: 145 false positives: 65 true negatives: 4636 false negatives: 154
# M3: LOGISTIC ERROR 0.0598
# -performance-
# true positives: 0 false positives: 0 true negatives: 4701 false negatives: 299
# M4: NAIVE BAYES ERROR 0.099
# -performance-
# true positives: 33 false positives: 229 true negatives: 4472 false negatives: 266
# transport : 0.15
# TRUE 27013
# FALSE 445693
# The best parameters are {'C': 10.0, 'gamma': 10.0} with a score of 0.92
# TRAINING SIZE 5000
# TRAINING TRUE: 750 CV TRUE: 307
# M1: SVC (LINEAR) ERROR 0.0556
# -performance-
# true positives: 34 false positives: 5 true negatives: 4688 false negatives: 273
# M2: SVC (GAUSSIAN) ERROR 0.0448
# -performance-
# true positives: 186 false positives: 103 true negatives: 4590 false negatives: 121
# M3: LOGISTIC ERROR 0.0614
# -performance-
# true positives: 0 false positives: 0 true negatives: 4693 false negatives: 307
# M4: NAIVE BAYES ERROR 0.1244
# -performance-
# true positives: 62 false positives: 377 true negatives: 4316 false negatives: 245
# transport : 0.2
# TRUE 27013
# FALSE 445693
# The best parameters are {'C': 100.0, 'gamma': 1.0} with a score of 0.90
# TRAINING SIZE 5000
# TRAINING TRUE: 1000 CV TRUE: 296
# M1: SVC (LINEAR) ERROR 0.0508
# -performance-
# true positives: 58 false positives: 16 true negatives: 4688 false negatives: 238
# M2: SVC (GAUSSIAN) ERROR 0.0406
# -performance-
# true positives: 206 false positives: 113 true negatives: 4591 false negatives: 90
# M3: LOGISTIC ERROR 0.0592
# -performance-
# true positives: 0 false positives: 0 true negatives: 4704 false negatives: 296
# M4: NAIVE BAYES ERROR 0.1418
# -performance-
# true positives: 88 false positives: 501 true negatives: 4203 false negatives: 208
# unionlabor : 0.05
# TRUE 23695
# FALSE 449011
# The best parameters are {'C': 10.0, 'gamma': 10.0} with a score of 0.96
# TRAINING SIZE 5000
# TRAINING TRUE: 250 CV TRUE: 244
# M1: SVC (LINEAR) ERROR 0.0488
# -performance-
# true positives: 0 false positives: 0 true negatives: 4756 false negatives: 244
# M2: SVC (GAUSSIAN) ERROR 0.0392
# -performance-
# true positives: 76 false positives: 28 true negatives: 4728 false negatives: 168
# M3: LOGISTIC ERROR 0.0488
# -performance-
# true positives: 0 false positives: 0 true negatives: 4756 false negatives: 244
# M4: NAIVE BAYES ERROR 0.0698
# -performance-
# true positives: 12 false positives: 117 true negatives: 4639 false negatives: 232
# unionlabor : 0.1
# TRUE 23695
# FALSE 449011
# The best parameters are {'C': 1000.0, 'gamma': 0.10000000000000001} with a score of 0.93
# TRAINING SIZE 5000
# TRAINING TRUE: 500 CV TRUE: 261
# M1: SVC (LINEAR) ERROR 0.0516
# -performance-
# true positives: 3 false positives: 0 true negatives: 4739 false negatives: 258
# M2: SVC (GAUSSIAN) ERROR 0.0436
# -performance-
# true positives: 118 false positives: 75 true negatives: 4664 false negatives: 143
# M3: LOGISTIC ERROR 0.0522
# -performance-
# true positives: 0 false positives: 0 true negatives: 4739 false negatives: 261
# M4: NAIVE BAYES ERROR 0.1034
# -performance-
# true positives: 46 false positives: 302 true negatives: 4437 false negatives: 215
# unionlabor : 0.15
# TRUE 23695
# FALSE 449011
# The best parameters are {'C': 100000.0, 'gamma': 0.001} with a score of 0.91
# TRAINING SIZE 5000
# TRAINING TRUE: 750 CV TRUE: 271
# M1: SVC (LINEAR) ERROR 0.0534
# -performance-
# true positives: 10 false positives: 6 true negatives: 4723 false negatives: 261
# M2: SVC (GAUSSIAN) ERROR 0.0414
# -performance-
# true positives: 160 false positives: 96 true negatives: 4633 false negatives: 111
# M3: LOGISTIC ERROR 0.0542
# -performance-
# true positives: 0 false positives: 0 true negatives: 4729 false negatives: 271
# M4: NAIVE BAYES ERROR 0.1202
# -performance-
# true positives: 54 false positives: 384 true negatives: 4345 false negatives: 217
# unionlabor : 0.2
# TRUE 23695
# FALSE 449011
# The best parameters are {'C': 1000000.0, 'gamma': 0.0001} with a score of 0.89
# TRAINING SIZE 5000
# TRAINING TRUE: 1000 CV TRUE: 237
# M1: SVC (LINEAR) ERROR 0.0446
# -performance-
# true positives: 28 false positives: 14 true negatives: 4749 false negatives: 209
# M2: SVC (GAUSSIAN) ERROR 0.0472
# -performance-
# true positives: 135 false positives: 134 true negatives: 4629 false negatives: 102
# M3: LOGISTIC ERROR 0.0474
# -performance-
# true positives: 0 false positives: 0 true negatives: 4763 false negatives: 237
# M4: NAIVE BAYES ERROR 0.1508
# -performance-
# true positives: 70 false positives: 587 true negatives: 4176 false negatives: 167

# %%
## See most important words - not very helpful
keywords = pd.DataFrame([t for t in zip(vectorizer.get_feature_names(),
                                        transformer.idf_)])
keywords.columns=('word','val')
keywords.sort('val', ascending=False)
# Out:
# /home/mvpolyakov/anaconda2/envs/py34/lib/python3.4/site-packages/ipykernel/__main__.py:5: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#                             word       val
# 5062                        pitt  7.625272
# 793                    blueprint  7.625272
# 5886                         ron  7.625272
# 6769                    theatric  7.625272
# 1523                    contrast  7.625272
# 1935                    dinowitz  7.625272
# 4117                       malon  7.625272
# 1937                 diploma_ged  7.625272
# 4119                malt_beverag  7.625272
# 790                        bloom  7.625272
# 3158                        hike  7.625272
# 791                  bloomington  7.625272
# 1944  dirk_bowi_knife_switchblad  7.625272
# 5874                      robust  7.625272
# 3143                      hester  7.625272
# 3176                  hjr_billno  7.625272
# 798                    bob_smith  7.625272
# 4169                    martinez  7.625272
# 1956                        disc  7.625272
# 1957                 disc_whatev  7.625272
# 1959                     discern  7.625272
# 3123                      heller  7.625272
# 4185                    matricul  7.625272
# 3116          heckler_koch_hk_hk  7.625272
# 3115                     heavili  7.625272
# 5849                         rim  7.625272
# 813     bonafid_collector_antiqu  7.625272
# 4191                        maui  7.625272
# 3174                  hiv_infect  7.625272
# 780                         bldg  7.625272
# ...                          ...       ...
# 7195                         use  1.685101
# 6836                        time  1.663798
# 4528                         new  1.658892
# 5494                        read  1.655635
# 3398                      includ  1.653546
# 5390                      purpos  1.650306
# 3237                        hous  1.632899
# 5720                      repres  1.622058
# 6102                     session  1.609558
# 3592                    introduc  1.607564
# 5377                      public  1.579405
# 5736                      requir  1.572327
# 963                            c  1.547213
# 6069                       senat  1.525361
# 2173                      effect  1.503976
# 5652                       relat  1.473894
# 491                      assembl  1.471959
# 4195                         may  1.467523
# 596                            b  1.396940
# 319                        amend  1.379341
# 5352                      provid  1.377757
# 2866                       gener  1.344025
# 6135                       shall  1.343005
# 3862                         law  1.318665
# 2705                      follow  1.314858
# 2255                       enact  1.246846
# 6037                     section  1.240231
# 121                          act  1.230010
# 750                         bill  1.165225
# 6426                       state  1.085423
#
# [7591 rows x 2 columns]

# %%
def createTable(dfList, fileName):
    colnames = ['issue', 'prop', 'cv-error', 'model', 'TP', 'FP', 'TN', 'FN', 'precision', 'recall', 'f1']
    table = pd.DataFrame(columns=colnames)
    for df in dfList: 
        # Store precision and recall in table
        df['precision'] = (df['TP'].astype('float64')/(df['TP'] + df['FP']).astype('float64'))
        df['recall'] = (df['TP'].astype('float64')/(df['TP'] + df['FN']).astype('float64'))
        df['f1'] = 2*(df['precision']*df['recall'])/(df['precision']+df['recall'])
        table = table.append(df)

    # Write to csv file
    table.to_csv(fileName)
    return(table)

# %%
def plot_precision_recall(table, issue_list, file):    
    plt.figure()
    plt.xlabel("Precision")
    plt.ylabel("Recall")
    plt.xlim(0.00, 1.01)
    plt.ylim(0.00, 1.01)
    plt.plot(table.precision[(table.model=="SVC (linear)")], table.recall[(table.model=="SVC (linear)")], 'o', color = "r", label = "svc - linear")
    plt.plot(table.precision[(table.model=="SVC (rbf)")], table.recall[(table.model=="SVC (rbf)")], 'o', color = "m", label = "svc - gaussian")
    plt.plot(table.precision[(table.model=="Logistic")], table.recall[(table.model=="Logistic")], 'o', color = "b", label = "logistic")
    plt.plot(table.precision[(table.model=="NaiveBayes")], table.recall[(table.model=="NaiveBayes")], 'o', color = "g", label = "naive bayes")

    plt.legend(loc="lower left")
    plt.savefig("precision-recall-" + file, format='png')
    
    for issue in issue_list:
        t = table[table.issue==issue]
        plt.figure()
        plt.xlabel("Precision")
        plt.ylabel("Recall")
        plt.xlim(0.00, 1.01)
        plt.ylim(0.00, 1.01)
        plt.plot(t.precision[(t.model=="SVC (linear)")], t.recall[(t.model=="SVC (linear)")], 'o', color = "r", label = "svc - linear")
        plt.plot(t.precision[(t.model=="SVC (rbf)")], t.recall[(t.model=="SVC (rbf)")], 'o', color = "m", label = "svc - gaussian")
        plt.plot(t.precision[(t.model=="Logistic")], t.recall[(t.model=="Logistic")], 'o', color = "b", label = "logistic")
        plt.plot(t.precision[(t.model=="NaiveBayes")], t.recall[(t.model=="NaiveBayes")], 'o', color = "g", label = "naive bayes")

        plt.legend(loc="lower left")
        plt.savefig("precision-recall-" + issue + file, format='png')
    
    plt.show()

# %%
def plot_f1(table, issue_list, file):   
    for issue in issue_list:
        t = table[table.issue==issue]
        plt.figure()
        plt.xlabel("Proportion")
        plt.ylabel("F1")
        plt.xlim(0.00, 0.25)
        plt.ylim(0.00, 1.01)
        plt.plot(t.prop[(t.model=="SVC (linear)")], t.f1[(t.model=="SVC (linear)")], 'o-', color = "r", label = "svc - linear")
        plt.plot(t.prop[(t.model=="SVC (rbf)")], t.f1[(t.model=="SVC (rbf)")], 'o-', color = "m", label = "svc - gaussian")
        plt.plot(t.prop[(t.model=="Logistic")], t.f1[(t.model=="Logistic")], 'o-', color = "b", label = "logistic")
        plt.plot(t.prop[(t.model=="NaiveBayes")], t.f1[(t.model=="NaiveBayes")], 'o-', color = "g", label = "naive bayes")

        plt.legend(loc="best")
        plt.savefig("f1-" + issue + file, format='png')
        plt.show()

# %%
t1 = createTable(issueList, "models-l1.csv")
t1[1:100]
# Out:
#         issue  prop cv-error         model   TP   FP    TN   FN  precision  \
# 0    abortion  0.05   0.0026     SVC (rbf)   10   12  4977    1   0.454545
# 0    abortion  0.05   0.0022      Logistic    0    0  4989   11        NaN
# 0    abortion  0.05   0.0106    NaiveBayes    7   49  4940    4   0.125000
# 0    abortion   0.1   0.0006  SVC (linear)    5    0  4992    3   1.000000
# 0    abortion   0.1    0.001     SVC (rbf)    8    5  4987    0   0.615385
# 0    abortion   0.1   0.0016      Logistic    0    0  4992    8        NaN
# 0    abortion   0.1    0.015    NaiveBayes    6   73  4919    2   0.075949
# 0    abortion  0.15    0.001  SVC (linear)    8    1  4987    4   0.888889
# 0    abortion  0.15   0.0032     SVC (rbf)   11   15  4973    1   0.423077
# 0    abortion  0.15   0.0024      Logistic    0    0  4988   12        NaN
# 0    abortion  0.15   0.0204    NaiveBayes   10  100  4888    2   0.090909
# 0    abortion   0.2    0.001  SVC (linear)    6    2  4989    3   0.750000
# 0    abortion   0.2    0.009     SVC (rbf)    9   45  4946    0   0.166667
# 0    abortion   0.2   0.0018      Logistic    0    0  4991    9        NaN
# 0    abortion   0.2   0.0266    NaiveBayes    5  129  4862    4   0.037313
# 0   education  0.05   0.0772  SVC (linear)    0    0  4614  386        NaN
# 0   education  0.05   0.0628     SVC (rbf)  144   72  4542  242   0.666667
# 0   education  0.05   0.0772      Logistic    0    0  4614  386        NaN
# 0   education  0.05    0.102    NaiveBayes   29  153  4461  357   0.159341
# 0   education   0.1   0.0718  SVC (linear)    6    2  4635  357   0.750000
# 0   education   0.1   0.0528     SVC (rbf)  178   79  4558  185   0.692607
# 0   education   0.1   0.0726      Logistic    0    0  4637  363        NaN
# 0   education   0.1     0.11    NaiveBayes   47  234  4403  316   0.167260
# 0   education  0.15   0.0674  SVC (linear)   36   19  4627  318   0.654545
# 0   education  0.15   0.0526     SVC (rbf)  220  129  4517  134   0.630372
# 0   education  0.15   0.0708      Logistic    0    0  4646  354        NaN
# 0   education  0.15   0.1276    NaiveBayes   84  368  4278  270   0.185841
# 0   education   0.2     0.07  SVC (linear)   82   46  4568  304   0.640625
# 0   education   0.2   0.0762     SVC (rbf)  256  251  4363  130   0.504931
# 0   education   0.2   0.0772      Logistic    0    0  4614  386        NaN
# ..        ...   ...      ...           ...  ...  ...   ...  ...        ...
# 0        guns   0.1   0.0086      Logistic    0    0  4957   43        NaN
# 0        guns   0.1   0.0366    NaiveBayes   15  155  4802   28   0.088235
# 0        guns  0.15   0.0072  SVC (linear)    8    5  4956   31   0.615385
# 0        guns  0.15   0.0108     SVC (rbf)   32   47  4914    7   0.405063
# 0        guns  0.15   0.0078      Logistic    0    0  4961   39        NaN
# 0        guns  0.15   0.0472    NaiveBayes   12  209  4752   27   0.054299
# 0        guns   0.2   0.0056  SVC (linear)   25    8  4947   20   0.757576
# 0        guns   0.2   0.0086     SVC (rbf)   40   38  4917    5   0.512821
# 0        guns   0.2    0.009      Logistic    0    0  4955   45        NaN
# 0        guns   0.2   0.0656    NaiveBayes   32  315  4640   13   0.092219
# 0      health  0.05   0.0984  SVC (linear)    0    0  4508  492        NaN
# 0      health  0.05    0.082     SVC (rbf)  115   33  4475  377   0.777027
# 0      health  0.05   0.0984      Logistic    0    0  4508  492        NaN
# 0      health  0.05   0.1232    NaiveBayes   21  145  4363  471   0.126506
# 0      health   0.1   0.0946  SVC (linear)    7    0  4520  473   1.000000
# 0      health   0.1   0.0676     SVC (rbf)  221   79  4441  259   0.736667
# 0      health   0.1    0.096      Logistic    0    0  4520  480        NaN
# 0      health   0.1   0.1336    NaiveBayes   68  256  4264  412   0.209877
# 0      health  0.15   0.0896  SVC (linear)   30    4  4522  444   0.882353
# 0      health  0.15    0.085     SVC (rbf)  271  222  4304  203   0.549696
# 0      health  0.15   0.0948      Logistic    0    0  4526  474        NaN
# 0      health  0.15   0.1548    NaiveBayes  120  420  4106  354   0.222222
# 0      health   0.2   0.0884  SVC (linear)   89   16  4469  426   0.847619
# 0      health   0.2    0.064     SVC (rbf)  335  140  4345  180   0.705263
# 0      health   0.2    0.103      Logistic    0    0  4485  515        NaN
# 0      health   0.2   0.1774    NaiveBayes  177  549  3936  338   0.243802
# 0   transport  0.05   0.0584  SVC (linear)    0    0  4708  292        NaN
# 0   transport  0.05   0.0506     SVC (rbf)   74   35  4673  218   0.678899
# 0   transport  0.05   0.0584      Logistic    0    0  4708  292        NaN
# 0   transport  0.05    0.078    NaiveBayes   13  111  4597  279   0.104839
#
#       recall        f1
# 0   0.909091  0.606061
# 0   0.000000       NaN
# 0   0.636364  0.208955
# 0   0.625000  0.769231
# 0   1.000000  0.761905
# 0   0.000000       NaN
# 0   0.750000  0.137931
# 0   0.666667  0.761905
# 0   0.916667  0.578947
# 0   0.000000       NaN
# 0   0.833333  0.163934
# 0   0.666667  0.705882
# 0   1.000000  0.285714
# 0   0.000000       NaN
# 0   0.555556  0.069930
# 0   0.000000       NaN
# 0   0.373057  0.478405
# 0   0.000000       NaN
# 0   0.075130  0.102113
# 0   0.016529  0.032345
# 0   0.490358  0.574194
# 0   0.000000       NaN
# 0   0.129477  0.145963
# 0   0.101695  0.176039
# 0   0.621469  0.625889
# 0   0.000000       NaN
# 0   0.237288  0.208437
# 0   0.212435  0.319066
# 0   0.663212  0.573348
# 0   0.000000       NaN
# ..       ...       ...
# 0   0.000000       NaN
# 0   0.348837  0.140845
# 0   0.205128  0.307692
# 0   0.820513  0.542373
# 0   0.000000       NaN
# 0   0.307692  0.092308
# 0   0.555556  0.641026
# 0   0.888889  0.650407
# 0   0.000000       NaN
# 0   0.711111  0.163265
# 0   0.000000       NaN
# 0   0.233740  0.359375
# 0   0.000000       NaN
# 0   0.042683  0.063830
# 0   0.014583  0.028747
# 0   0.460417  0.566667
# 0   0.000000       NaN
# 0   0.141667  0.169154
# 0   0.063291  0.118110
# 0   0.571730  0.560496
# 0   0.000000       NaN
# 0   0.253165  0.236686
# 0   0.172816  0.287097
# 0   0.650485  0.676768
# 0   0.000000       NaN
# 0   0.343689  0.285254
# 0   0.000000       NaN
# 0   0.253425  0.369077
# 0   0.000000       NaN
# 0   0.044521  0.062500
#
# [99 rows x 11 columns]

# %%
plot_precision_recall(t1, issues, "prop-l1.png")
plot_f1(t1, issues, "prop-l1.png")

# %%
def best_performers(performance):
    df = pd.DataFrame()
    df1 = pd.DataFrame()
    df2 = pd.DataFrame()
    df3 = pd.DataFrame()

    for issue in issues:
        maxF1 = max(performance.f1[performance.issue==issue])
        maxPrecision = max(performance.precision[performance.issue==issue])
        maxRecall = max(performance.recall[performance.issue==issue])
        #print(issue)
        #print(maxF1, maxPrecision, maxRecall)

        df1=df1.append(performance[(performance.f1==maxF1) & (performance.issue==issue)])
        df2=df2.append(performance[(performance.precision==maxPrecision) & (performance.issue==issue)])
        df3=df3.append(performance[(performance.recall==maxRecall) & (performance.issue==issue)])

        df1['best'] = 'F1'
        df2['best'] = 'Precision'
        df3['best'] = 'Recall'

    df = df.append(df1)
    df = df.append(df2) 
    df = df.append(df3)    
    return(df)

# %%
col1 = ['best', 'model', 'issue', 'prop', 'TP', 'FP', 'TN', 'FN', 'cv-error', 'precision', 'recall', 'f1']
t1_best = best_performers(t1)
t1_best = t1_best[col1]
t1_best.to_csv("best-prop-models-l1.csv", index=False)

t1_best
# Out:
#         best         model        issue  prop   TP   FP    TN   FN cv-error  \
# 0         F1  SVC (linear)     abortion   0.1    5    0  4992    3   0.0006
# 0         F1     SVC (rbf)         guns   0.1   37   31  4926    6   0.0074
# 0  Precision  SVC (linear)     abortion  0.05    1    0  4989   10    0.002
# 0  Precision  SVC (linear)     abortion   0.1    5    0  4992    3   0.0006
# 0  Precision  SVC (linear)         guns   0.1    7    0  4957   36   0.0072
# 0     Recall     SVC (rbf)     abortion   0.1    8    5  4987    0    0.001
# 0     Recall     SVC (rbf)     abortion   0.2    9   45  4946    0    0.009
# 0     Recall     SVC (rbf)    education   0.2  256  251  4363  130   0.0762
# 0     Recall     SVC (rbf)       energy   0.2  111  195  4644   50    0.049
# 0     Recall     SVC (rbf)  environment   0.1   59  123  4789   29   0.0304
# 0     Recall     SVC (rbf)         guns   0.2   40   38  4917    5   0.0086
# 0     Recall     SVC (rbf)       health   0.2  335  140  4345  180    0.064
# 0     Recall     SVC (rbf)    transport   0.2  206  113  4591   90   0.0406
# 0     Recall     SVC (rbf)   unionlabor  0.15  160   96  4633  111   0.0414
#
#    precision    recall        f1
# 0   1.000000  0.625000  0.769231
# 0   0.544118  0.860465  0.666667
# 0   1.000000  0.090909  0.166667
# 0   1.000000  0.625000  0.769231
# 0   1.000000  0.162791  0.280000
# 0   0.615385  1.000000  0.761905
# 0   0.166667  1.000000  0.285714
# 0   0.504931  0.663212  0.573348
# 0   0.362745  0.689441  0.475375
# 0   0.324176  0.670455  0.437037
# 0   0.512821  0.888889  0.650407
# 0   0.705263  0.650485  0.676768
# 0   0.645768  0.695946  0.669919
# 0   0.625000  0.590406  0.607211

# %%
### Plot error rates ###

for issue in issues:
    plt.figure()
    plt.title('Issue: ' + issue)
    
    s = t1[(t1.issue==issue) & (t1.model!="NaiveBayes")]
    plt.xlabel("Proportion True")
    plt.ylabel("Type I and Type II Errors")
    plt.ylim(0, max(max(s.FP), max(s.FN)))
    
    plt.plot(s.prop[s.model=="SVC (linear)"], s.FP[s.model=="SVC (linear)"], '-', color = "r", label = "FP: svc-linear")
    plt.plot(s.prop[s.model=="SVC (linear)"], s.FN[s.model=="SVC (linear)"], '-', color = "b", label = "FN: svc-linear")
    plt.plot(s.prop[s.model=="SVC (rbf)"], s.FP[s.model=="SVC (rbf)"], ':', color = "r", label = "FP: svc-gaussian")
    plt.plot(s.prop[s.model=="SVC (rbf)"], s.FN[s.model=="SVC (rbf)"], ':', color = "b", label = "FN: svc-gaussian")
    plt.plot(s.prop[s.model=="Logistic"], s.FP[s.model=="Logistic"], '-.', color = "r", label = "FP: logistic")
    plt.plot(s.prop[s.model=="Logistic"], s.FN[s.model=="Logistic"], '-.', color = "b", label = "FN: logistic")
    #plt.plot(s.prop[s.model=="NaiveBayes"], s.FP[s.model=="NaiveBayes"], ':', color = "r", label = "FP: naive bayes")
    #plt.plot(s.prop[s.model=="NaiveBayes"], s.FN[s.model=="NaiveBayes"], ':', color = "b", label = "FN: naive bayes")
    
    plt.legend(loc="best")
    plt.savefig('l1-prop-error-rate-' + issue + '.png', format='png')
    plt.show()

# %%
'''def tokens_from_text(text):
    def stem(word):
        # Some non-word strings ('aed') that happen to be in the text can trip up the stemmer
        try:
            return porter.stem(word)
        except:
            return word
            
    pre_tok = gensim.utils.tokenize(text, lowercase=True, deacc=True, errors="ignore")
    tokens = [stem(word) for word in pre_tok if word not in stoplist]
    if bigram and trigram:
        return trigram[bigram[tokens]]    
    else:
        return tokens'''

# %%
'''def generate_ngram_models(bills):
    global bigram
    global trigram

    by_state = {}
    
    bg = None
    tg = None
    
    print("generating bigram model")
    for state in bills.state.unique():
        print(state)
        # create token array by state 
        tokens = []
        for t in bills.ix[bills.state==state, 'bill_text']:
            tokens.append(tokens_from_text(t))
        
        by_state[state] = tokens
        if bg:
            bg.add_vocab(tokens)
        else:
            bg = gensim.models.Phrases(tokens, threshold=30)  # 60 is good if by itself - look at a small sample!        
    
    # separate local and global variables in case fails half way for some reason
    bigram = bg
    
    print("generating trigram model")
    for state in bills.state.unique():
        print(state)
        tokens = []

        if tg:
            tg.add_vocab(bigram[ by_state[state] ])
        else:
            tg = gensim.models.Phrases(bigram[by_state[state]], threshold=30) # with trigrams, 30 and 30 work well - CHECK WHEN ADDING NEW TEXT
    trigram = tg
                
bi_model_name = '/home/mvpolyakov/datasci/leg_topic_model/bigram.model'
tri_model_name = '/home/mvpolyakov/datasci/leg_topic_model/trigram.model'
try:
    bigram = pickle.load(open(bi_model_name, 'rb'))
    trigram = pickle.load(open(tri_model_name, 'rb'))
except:    
    generate_ngram_models(bills)
    pickle.dump(bigram, open(bi_model_name, 'wb'))
    pickle.dump(trigram, open(tri_model_name, 'wb'))'''
# Out:
# 'def generate_ngram_models(bills):\n    global bigram\n    global trigram\n\n    by_state = {}\n    \n    bg = None\n    tg = None\n    \n    print("generating bigram model")\n    for state in bills.state.unique():\n        print(state)\n        # create token array by state \n        tokens = []\n        for t in bills.ix[bills.state==state, \'bill_text\']:\n            tokens.append(tokens_from_text(t))\n        \n        by_state[state] = tokens\n        if bg:\n            bg.add_vocab(tokens)\n        else:\n            bg = gensim.models.Phrases(tokens, threshold=30)  # 60 is good if by itself - look at a small sample!        \n    \n    # separate local and global variables in case fails half way for some reason\n    bigram = bg\n    \n    print("generating trigram model")\n    for state in bills.state.unique():\n        print(state)\n        tokens = []\n\n        if tg:\n            tg.add_vocab(bigram[ by_state[state] ])\n        else:\n            tg = gensim.models.Phrases(bigram[by_state[state]], threshold=30) # with trigrams, 30 and 30 work well - CHECK WHEN ADDING NEW TEXT\n    trigram = tg\n                \nbi_model_name = \'/home/mvpolyakov/datasci/leg_topic_model/bigram.model\'\ntri_model_name = \'/home/mvpolyakov/datasci/leg_topic_model/trigram.model\'\ntry:\n    bigram = pickle.load(open(bi_model_name, \'rb\'))\n    trigram = pickle.load(open(tri_model_name, \'rb\'))\nexcept:    \n    generate_ngram_models(bills)\n    pickle.dump(bigram, open(bi_model_name, \'wb\'))\n    pickle.dump(trigram, open(tri_model_name, \'wb\'))'
