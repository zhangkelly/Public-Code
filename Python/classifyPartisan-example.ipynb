# %%
import lxml
import re
import requests
import tweepy
import csv, json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import string
from bs4 import BeautifulSoup
from tweepy import OAuthHandler
from nltk import PorterStemmer
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
huffington = pd.read_csv('huffington_tokens.csv', index_col=0)
huffington = huffington[0:1000]
X_huffington = huffington['text'].tolist()
X_huffington = [str(x) for x in X_huffington]
y_huffington = [False]*len(X_huffington)

print(len(y_huffington),len(X_huffington))
# Out:
# 1000 1000

# %%
huffington2 = pd.read_csv('huffington_tokens_w2.csv', index_col=0)
huffington2 = huffington2[0:1000]
X_huffington2 = huffington2['text'].tolist()
X_huffington2 = [str(x) for x in X_huffington2]
y_huffington2 = [False]*len(X_huffington2)

print(len(y_huffington2),len(X_huffington2))
# Out:
# 1000 1000

# %%
breitbart = pd.read_csv('breitbart_tokens.csv', index_col=0)
X_breitbart = breitbart['text'].tolist()
X_breitbart = [str(x) for x in X_breitbart]
y_breitbart = [True]*len(X_breitbart)
print(len(y_breitbart),len(X_breitbart))
# Out:
# 1045 1045

# %%
breitbart2 = pd.read_csv('breitbart_tokens_w2.csv', index_col=0)
X_breitbart2 = breitbart2['text'].tolist()
X_breitbart2 = [str(x) for x in X_breitbart2]
y_breitbart2 = [True]*len(X_breitbart2)
print(len(y_breitbart2),len(X_breitbart2))
# Out:
# 1045 1045

# %%
X = X_breitbart + X_huffington
y = y_breitbart + y_huffington
      
partisan_data = pd.DataFrame({"source": y, "text": X})
partisan_data = partisan_data[partisan_data.text.isnull()==False]    
partisan_data.to_csv("partisan.csv")
partisan_data.head()
# Out:
#   source                                               text
# 0   True  jordan said we moving lot quicker repeal healt...
# 1   True  isnt dam its primary storage facility located ...
# 2   True  after days deliberating extremely disappointin...
# 3   True  coincidence i want thank president agent orang...
# 4   True  emergency order extends butte sutte yuba count...

# %%
X2 = X_breitbart2 + X_huffington2
y2 = y_breitbart2 + y_huffington2
      
partisan_data2 = pd.DataFrame({"source": y2, "text": X2})
partisan_data2 = partisan_data2[partisan_data2.text.isnull()==False]    
partisan_data2.to_csv("partisan2.csv")
partisan_data2.head()
# Out:
#   source                                               text
# 0   True  global traffic research firm inrix reports ang...
# 1   True  realtor chad curry recently talked home buyer ...
# 2   True  etown college dems @etowncollegedem  campaign ...
# 3   True  resolution states austin isd policy bars any a...
# 4   True  friday one hundred protesters affiliated phill...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1234)
X, X_cv, y, y_cv = train_test_split(X, y, test_size=0.30, random_state=1234)
X_train[1:10]
# Out:
# ['research heritage foundation shows carbon tax little help environment average american heritage foundation study analyzed  per ton tax carbon similar bakers  tax per ton carbon think tank study suggests effects carbon tax would be carbon tax would reduce global temperatures much either according heritage foundation study united states cut carbon emissions immediately would  degree celsius drop global temperature industrialized nations eliminated carbon emissions would  degree celsius drop global temperature.climate activists epa administrators lisa jackson gina mccartney former secretary state john kerry admit substantial reduction american carbon emissions substantially impact global co levels united nations climate chief christiana figueres admitted ulterior motives enacting carbon tax figeures told reporters this probably difficult task ever given ourselves intentionally transform economic development model first time human history continued this first time history mankind setting task intentionally within defined period time change economic development model reigning least  years–since industrial revolution',
#  'los angeles county sheriffs bomb squad summoned investigate package consequently shut hollywood station corner hollywood blvd highland moreover safety precautions nearby stations universal/studio city hollywood/western also temporarily closed reported abc 7 two hours later shortly  p.m bomb squad officials determined black backpack threat member sheriffs department seen carrying large bag station unfortunately rush hour commuters scare set commuting nightmare metro line well surrounding freeways people told abc waited well hour downtown area metro department send shuttle buses transport universal red line station spectacular traffic jams caused metro riders delayed three hours nobody gave information children old people went thats horrible said martha williams lives north hollywood besides streets jammed cars sidewalks filled well several buildings evacuated including landmark tcl chinese el capitan theaters',
#  '― house minority leader nancy pelosi d-calif said thursday would eagerly back legislation requiring president donald trump take mental exam version idea first put forward rep jason chaffetz r-utah chairman house oversight government reform committee told editorial board last week wasnt talking rhetoric thats flying around trump but if youre going hands nuclear codes probably know kind mental state youre in pelosi echoed thought briefing thursday i cant wait introduces legislation able join co-sponsor that said i think its good idea steadfast opponents trump citing mental health even election reason remove office 25th amendment u.s constitution stipulates president may removed two-thirds vote congress members executive branch determine unable discharge duties particular section amendment never deployed depose president though howard baker jr became president ronald reagans chief staff warned may need invoke it given reagans deteriorating condition baker determined ultimately unnecessary reagan fit serve term aide chaffetz said bill would apply presidential candidates future trump already filed re-election removing trump would make vice president mike pence strong backing capitol hill president thats scenario trump backers long dreaded always assumed would come impeachment instead ann coulter strong trump backer campaign slammed choice pence running mate chosen warning heightened risk hed removed establishment-friendly president if trump chooses vice president supports cheap labor donor class long parties decide impeach president trump coulter wondered if consultants prevail trump [and chooses pence hope conventional wisdom vice presidents irrelevant correct ― least six months trump presidency impeachment',
#  'jaime camil proud respectful way jane virgin portrayed latinos mexican-born actor plays janes dad rogelio de la vega spoke mic recently role show latino stereotypes hollywood camil explained one cw shows strengths treat latino characters interview camil also discussed narrow-minded stereotypes still impact mexicans specifically portrayed hollywood you dont portray mexicans nannies gardeners rapists drug dealers mexico cosmopolitan films show that said referencing trumps infamous remarks mexican immigrants  interview latina magazine actor also spoke industry doesnt understand diversity complexity power latino demographic hollywood make latinos certain physical type certain name whatever… its easy camil told magazine latino stars often cast its wanting movie american actor say hey listen either johnny depp carrot top youll go dude fucking insane really putting guys category answer would be well yes theyre americans films thats kind way explain',
#  'excited celebrate valentines day looking support local bookstore dedicated registering dissent president donald j trump administration well three once new event called bury white house books valentines day urging opponents trumps agenda protest sending president mountains least favorite form entertainment event launched aaron hamburger stacie whitaker leaders readers newly founded group donald trump doesnt books section reads lets love literature  hopes better world deluging oval office flood great books hamburger whitaker writers met mfa program hamburger teaches whitaker student belief importance reading all recent presidents republican democratic readers pointed hamburger post part leader knowing means sit audience listen theres nothing humbling informing reading taking voice consciousness someone else deep way added this much movement stand proudly declare for namely republic letters rather fear others practical concerns i would rather send book already have commented one is ok send president used book lets frank other matter many times thoughtfully publish helpful diverse reading lists president trump matter many volumes serious presidential biographies slyly slipped onto nightstand intellectual advisors trump almost definitely isnt going them evidence accumulated years suggests new york times put it the president  books activist organizers often urge citizens flood representatives snail mail phone calls direct inconvenience causes politicians staffers ensures issue hand isnt ignored hamburger says inspired revelation nyt trump doesnt read a asking people send mountain letters white house demonstrate support affordable care act book shipment inspired twist this though gigantic shipment individually packaged books ― unwrapped examined dealt ― might seem windfall bookworms also major burden clogging mailrooms staff resources trust one neither trump staff likely take reading recommendations campaign flooding white houses mail system books frederick douglass environment could serious annoyance correction previous version incorrectly stated aaron hamburger student mfa program updated reflect teacher program',
#  'gigi hadid made first appearance the ellen degeneres show thursday spent time chatting ex-one direction boyfriend zayn malik 21-year-old model recently launched clothing line tommy hilfiger dating malik a year half told ellen first met we actually met friends birthday party years ago new york come victorias secret show last year think ended coming hadid said i ill play cool ill go after-party wasnt there later week two finally went first date ellen asked duo playing cool date we played cool for like  minutes like youre really cute said we connected like really quickly kind sense humor started sharing videos one videos hadid said featured noah ritter child now-viral video said said word apparently again celebrity couples ― theyre us',
#  'president donald trumps nomination federal appeals court judge neil gorsuch end nuclear option showdown senate minority leader chuck schumer d-n.y argued wednesday gorsuch pass 60-vote hurdle supreme court nominees achieve schumer said senate floor speech doesnt trump nominate someone else least eight democrats need vote gorsuch confirm him senate majority leader mitch mcconnell r-ky could also invoke nuclear option changing senate rules midstream end filibusters allowing gorsuch pass  votes those say end process two possible results senate confirm nominee republicans use nuclear option change rules senate dead wrong false choice schumer said nominee cannot get  votes then problem lies senate nominee added the answer change rules senate change nominee mainstream candidate merrick garland president barack obamas nominee court  never got vote schumer saying democrats vote candidate time around consider mainstream mcconnell declined say whether would go nuclear saying hugh hewitt radio program expected gorsuch succeed much conservative justice samuel alito did schumer however suggested similar judge would longer acceptable saying high court chief justice john roberts already shifted far right far favor big business judge gorsuch consistently favored corporate interests rights working people schumer said in one cases sided employee republican woman alleged fired conservative also argued gorsuch shown hostile people use courts pursue cases powerful favorable moneyed interests want unlimited campaign spending opposed landmark abortion rights decision roe v wade it seems president trump said would working man woman chosen someone routinely sides average american schumer said schumer also argued essential democrats hold gorsuch especially high standards judge shows ideological bent could problematic trump administration this administration seems little regard rule law likely test constitution ways hasnt challenged decades schumer said new york democrat pointed trumps executive orders presidents decision fire sally yates acting attorney general disagreed presidents order targeting muslims refugees many lived first weeks several administrations parties schumer said this even close normal',
#  'films love open eyes unseen narratives different ways being carefully woven plots complex characters films love because one lazy summer fifth sixth grade watched again memorized lines found unhealthy relationships romantic leads its latter category brings many drunk feminist films dff ― space feminists simultaneously indulge criticize many hollywood movies whose representations race gender sexuality class flawed completely absent its laughable may realized preteen example ridiculously sex work portrayed pretty woman creepily virginity framed crossroads single queer person speaks either dff offers live events well webisodes online media allow women watch films love without letting hook providing drunken commentary pokes fun shortcomings tropes mainstream hollywood films women state website we aim jokes oppressor system and sometimes fashion experiencing oppression first film drunkenly mocked group hilarious socially conscious ladies everyones favorite vampire love story twilight gillian goerz one dffs founders hate-read way books and many curious see bella edward would play screen drafted drinking game would inject feminist exegesis supernatural romance or least would get drunk goerz invited friends participate including dff co-founders amy wood steph guthrie shaunna bruton movement born success twilight drinking game dff team decided would fun film future rounds youtube also set account soliciting requests films dff tear into recruited larger cast ensuring dff ringleaders would embody diverse representation demanding movies expanding original four founders cast important us goerz told post it initially four white women didnt think ok wanted reach soon people interested idea didnt want front center today dff  rotating cast members who theyre smashing patriarchy work comedians writers social workers public servants designers participate dff making pre-recorded youtube videos hosting live events often held torontos arthouse theater royal cinema in-person happenings regularly sell out invite angry viewers yell screen throw things release pent-up tension comes secretly loving save last dance despite knowing julia stiles absolutely rhythm none i think its way sort alleviate guilt cast member resh brown said phone interview post especially movies came folks younger able enjoy movies together also hate trash them think its way connect around films bring lot feelings inside goerz agreed a lot movies resh said element nostalgia think something commiserating people helps make peace problematic past able appreciate good ignoring bad part growing up its forgiving way handle beliefs first element dff screening choosing film ― somewhat lovable movie blindspots terms representation truthful empathetic storytelling sadly plenty options past showings included films the craft gone girl spice world bollywood/hollywood fifty shades grey some bridesmaids progressive hollywood standards ― features female-led cast however goerz put it you cant gloss weird racist jokes there showing film live drunk audience dff team test screening theyll sketch questions point details discussed love actually example drink triggers include sexy man boss ― whenever older male boss becomes romantically involved younger female subordinate theres also less political turt alert ― drink every heinous turtleneck featured screen many many drinking games rules however emerge fly moviegoers shout suggestions seats live-tweeters chime using evenings previously selected hashtag dff hosts update audience accordingly its something join on goerz said the hosts also say words screening film starts personal experience film point problematic lovable interest one unifying factor aligning dffs chosen films ― range romantic dramas thrillers slapstick comedies ― made within last  years then brown explained films often problematic dated felt uncomfortable even recommending them we want viewers get something film beyond hate-watching said although older films often glaringly exasperating te ...
#  "slew celebrities happy armours ceo kevin plank interview cnbc tuesday plank called president donald trump highly passionate real asset country naturally many stars affiliated athletic apparel brand ― well fans brand ― something say statements golden state warriors steph curry one first opinion interview san jose mercury news marcus thompson wednesday curry said agreed planks description trump if remove et asset curry alone opinion joined thursday actor dwayne the rock johnson actress emmy rossum professional ballerina misty copeland shared messages social media johnson posted memos stating felt planks words were divisive lacking perspective appreciate welcome feedback people disagree and agree kevin plank's words cnbc neither words beliefs words divisive lacking perspective inadvertently creating situation personal political opinions uas partners employees overshadowed comments ceo good company solely defined ceo good company defined athlete celebrity partners them good company single person good company team group brothers sisters committed working together every day provide families one another clients serve dont partner brand casually partner brands trust people values means commitment diversity inclusion community open-mindedness serious hard work doesn't mean team always agree opinion everyone works there including executives great leaders inspire galvanize masses turbulent times don't cause people divide disband responsibility global audience serve also thousands workers pour blood sweat tears making armour strong diverse group hardworking men women possess integrity respect compassion one another world live in debate healthy time widespread disagreement loyalty feel obligation stand diverse team american global workers beating heart soul armour reason chose partner them commitment real sweat callouses thicken daily #committedtothepeople photo posted therock @therock feb  10:36am pst rossum shared brief tweet indicating shed renouncing brand entirely copeland posted instagram say reached plank directly hope take public action clearly communicate reflect common values order effectively continue work towards shared goal trying motivate people best selves always appreciated great support platform armour given represent community gender career world stage however strongly disagree kevin plank's recent comments support trump recently reported supported followed career know one topic i've never backed away speaking openly importance diversity inclusion imperative partners sponsors belief spoken length kevin privately matter someone takes responsibility role model seriously important he ua take public action clearly communicate reflect common values order effectively continue work towards shared goal trying motivate people best selves photo posted misty copeland @mistyonpointe feb  10:14am pst despite statements online however johnson copeland curry cut ties armour completely yet hashtags #boycottunderarmour #grabyourwallet surged since planks comments celebrities responses brand also released statement friday morning stress engage[s policy politics against travel ban believe[s immigration source strength diversity innovation global companies based america armour"]

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size=0.30, random_state=1234)
X2, X_cv2, y2, y_cv2 = train_test_split(X2, y2, test_size=0.30, random_state=1234)
X_train2[1:10]
# Out:
# ['although author piece writes milo negative terms also notes editors performance maher would make viewers wonder leftists rioting him also notes mahers scorn liberals take bait milo heard much yiannopoulos without ever exposed yes live liberal bubble defense air much cleaner here chief reaction controversial figure watching show wonder this people rioting over lightweight russell brand wannabe maher seemed less offended guest admittedly best behavior liberals scorned taking bait impish british fag sitting next him concluded scheck otherwise show fairly typical episode full article hollywood reporter',
#  'sunday abcs this week sen rand paul r-ky addressed sen john mccains r-az criticism trump administration karl think its fair say second none senate comes fighting civil liberties let ask specifically hes saying press saying media enemy american people agree that paul its something would say would say bias think its fair point bias media sides right left its hard find objective gotten particularly watch cable news its dominated opinion polarized comes people comes media would say dont see criticism somehow people think separation powers means president cant criticize judiciary no nothing that thats sort political sensibilities nothing constitution separation powers dont see sort treads things separation powers legislative powers isnt discussion words would separate again words actual real legislative action someone tries put limits press ill first one standing right press left right continue saying part discussion forwarding discussion karl would make mccains statement were creeping towards situation people potentially supportive dictatorship country top concern paul think senator mccains perspective colored disagreements president trump foreign policy look foreign policy would say john mccain wrong everything last four decades advocated iraq war think destabilized middle east look map theres probably least six different countries john mccain advocated u.s boots ground john mccains complaint were either war somewhere were war leave soon were soon enough wants stay forever wherever send troops thats foreign policy odds president trump also idea engagement idea foreign policy realism think fits neatly president trump john mccain neoconservative label lets make world safe democracy were going topple every regime hasnt worked mean intervention destabilize assad regime really made chaos worse syria get rid assad today would actually worry  million christians protected assad think its foreign policy debate trump mccain opposite sides debate tend sympathize president need change dont need continue regime change throughout world nation-building its expensive dont enough money rebuild country were rebuilding everyone elses countries karl clarify mccain said specifically dictators get started limiting freedom press imagine agree that paul well thing is dont agree analysis applying president havent seen legislation coming forward wants limit press see president trump expressing opinion rather forceful know distinct way see evidence anybody putting forward kind legislation limit press think people know colored john mccains disagreement president trump is everything says president colored personal dispute got running president trump taken grain salt john mccain guy advocated war everywhere would bankrupt nation actually were lucky john mccain charge think would perpetual war',
#  'language barriers real struggle traveling never fear japan clever solution english-speaking visitors officials iwate prefecture developed lineup tourism signs display info menu choices payment options locker room etiquette simple illustrated form signs already display around city morioka regional development director told japan times theyre intended make english-speaking tourists feel welcome area added many signs dining also provide advice using onsens japans popular hot spring baths information visiting japans iwate prefecture check lonely planets guide',
#  'much made monetary cost president donald trumps proposed border wall trump cited wildly differing estimates senate majority leader mitch mcconnell r-ky recently said wall would cost  billion  billion experts cited numbers far higher walls true cost surpasses even biggest numbers discussed theres upkeep course hundreds millions dollars per year needed maintain 1000-mile barrier expenses too intangible difficult quantify political blowback could significant mexican president enrique peña nieto already canceled meeting trump wall calling disrespect mexico americas third-largest trading partner close ally impacts native tribes border communities migrant populations projected immense then theres potential damage environment locally beyond environmentalists say wall climate change disrupt natural water flows profoundly affect native species habitats let blunt benefits border wall many risks dan millis coordinator sierra clubs borderlands program told huffpost month we dont concerns border wall impacts millis said thats already walls barriers along  miles u.s.-mexico border existing fences served intended purpose said already cost taxpayers billions dollars resulted wide array unintended damaging consequences research suggests existing barriers effective restricting movement people report released week government accountability office found border fencing breached  times  2015 barriers however proven formidable foe migrating animals  study found security barriers arizona-mexico border little prevent crossings humans restricting movements native species pumas coatis raccoon-like creature thus limiting access food water habitat there significant difference number migrants present areas wall compared areas wall jamie mccallum lead author study told huffpost interview last year in words wall seem job intended for barriers however could driving native species a possible collapse population study said migration corridors critical health survival wildlife along border endangered animals jaguars ocelots live u.s movements mexico species including bighorn sheep pygmy owls gray wolves black bears travel back forth across border access vital resources maintain genetic diversity clinton epps wildlife biologist oregon state university told bbc last year species crossing border millions years physical barrier said could fundamentally alter health behavior populations wall also stifle ability species adapt changing climate imagine instance herd deer endangered species jaguar needed move north higher elevation order adapt higher temperatures lower rainfall a wall impedes movement particular herd ― even entire species ― put risk said millis beyond disruption migratory movements border infrastructure could also fragment destroy habitats sergio avila-villegas conservation research scientist tucsons arizona sonora desert museum told bbc wall would effects ecosystem whole u.s fish wildlife service estimated  endangered species  migratory bird species would affected unbroken barrier along entire land border u.s mexico reported outside magazine bald eagle california condor several sea turtles west indian manatee among species would potentially threatened wall natural water flows across mexican border also would affected existing barriers already led problems erosion flooding sedimentation border communities arizona example border fences cause increased flooding border wall could additionally significant contributor global warming the production concrete wall one trump suggested would produce lot greenhouse gases since cement production coal-fired carbon-intensive process said millis according mit technology review trumps wall would contain 9 million cubic meters concrete 2 billion kilograms steel production would produce 7 million metric tons carbon dioxide emissions for context thats emissions  homes course year wrote magazine and thats low end ongoing maintenance re-routing traffic unforeseen consequences could push figure far higher environmentalists  ...
#  '― u.s intelligence law enforcement agencies confirmed president donald trumps campaign aides associates constant contact russian intelligence officials election directly contradicting public statements made top administration officials jan  shortly trump took office vice president mike pence repeatedly said television zero contacts campaign russian officials just button one question adviser anybody trump campaign contact russians trying meddle election cbs face nation host john dickerson asked of course not pence replied pence also answered of course not asked similar question day fox sunday host chris wallace adding all contact trump campaign associates american people trump also denied interactions according nbc jan 11 trump specifically address questions regarding whether members staff contact russian officials campaign nbc repeated question trump afterwards president-elect approached elevator exit room answered no tuesday white house secretary sean spicer seemed stand earlier denials theres nothing would conclude anything different changed respect time period spicer said tuesday night multiple outlets reported u.s intelligence law enforcement agencies obtained phone records intercepted calls showed trump associates campaign aides repeatedly talking russian officials year election its clear discussing far evidence actively colluding help trump defeat democrat hillary clinton according cnn u.s investigators concerned russian officials bragging special access trump ― although russians could exaggerating matter its also possible spicer pence dark intelligence law enforcement findings made comments trump not president barack obama briefed extensive contact russian operatives trump aides its clear briefings took place pence left uncomfortably defend trump administration officials before repeatedly told former national security adviser michael flynn discuss sanctions russian officials inauguration though that too turned false flynn resigned monday night evidence piled hed discussions pence reportedly particularly upset whole affair since left egg face additionally flynn blamed faulty memory rather fully apologize pence',
#  'former scientologist leah remini said tom cruise could singlehandedly end scientology friday night episode real time bill maher king queens star whose a&e docuseries scientology aftermath aims show organization negatively affects members appeared show host maher let alt-right poster child milo yiannopoulos light teasing banter actress confirmed even celebrity supporters cruise john travolta required conform many organizations strict rules members including hours studying day he [cruise could end singlehandedly maher interjected he could end this correct remini said adding because saying singlehandedly clearing planet changing planet scientologists believe scientology clearing planet process body thetans aliens members believe inhabit planet eliminated actress previously stressed highly scientology members regard mission impossible actor called messiah milo youve got nothing scientology shit maher joked one point interview cruise could use influence hit back scientology doesnt seem anytime soon actor one organizations prominent supporters according remini rules often bent him that part hypocrisy said members organization remini explained even taught think actors failures ―  flop jack reacher ― due suppressive people detractors scientology herself working him scientologists believe didnt make [reacher hit suppressive evil people working him hes winning life clearing planet said catch whole thing above',
#  'it exactly funny tweet martha stewart fact martha stewart multi-millionaire driving ford truck enormous yellow snow plow attached front it maybe its middle nowhere middle nowhere martha stewart impossible imagine car ended simultaneously front trees behind pile snow confused look barely make face could grammatically hollow caption i decided plow stuck darn impossible decipher tone perhaps its cannot tell took photo person actually happy there knows find funny tweet martha stewart funny is',
#  'rapper busta rhymes hold back grammy awards sunday rhymes joined rap group tribe called quest grammy-nominated artist anderson .paak politically-charged performance rhymes called president donald trump immigration ban thank you president agent orange evil youve perpetuating throughout united states rhymes said i want thank president agent orange unsuccessful muslim ban rappers introduced stage singer solange dedicated performance late great atcq group member phife dawg performed groups latest hit single we people joined parade diverse individuals onstage including muslim women wearing hijabs raised fists chanted alongside rappers collectively recited resist watch epic performance full below',
#  'harvard university scientist told guardian week team two years resurrecting traits woolly mammoth went extinct last ice age goal create embryo thats hybrid woolly mammoth closest living relative asian elephant our aim produce hybrid elephant-mammoth embryo researcher george church told guardian actually would elephant number mammoth traits church explained huffpost last year process involves retrieving dna mammoth remains preserved frozen tundra splicing dna genome asian elephant species closely related would able breed alive today church noted project plenty critics including conservationists call gimmick say idea de-extinction diverts attention efforts conserve species still alive church part said efforts would improve conservation endangered asian elephants engineering better adapted cold thus allowing live expanded territory i call cold-resistant asian elephants church told huffpost  interview church said envisions hybrid creatures living tundras russia canada argued presence could help stave effects climate change wrote scientific american mammoths could keep region colder by a eating dead grass thus enabling sun reach spring grass whose deep roots prevent erosion b increasing reflected light felling trees absorb sunlight c punching insulating snow freezing air penetrates soil poachers seem far less likely target arctic mammoths african elephants church team plan grow hybrid animal artificial womb due ethical concerns recruiting living female elephant process skeptics say artificial womb scheme serious shortcomings churchs team proposing rear embryo artificial womb seems ambitious say least ― resultant animal would deprived pre-birth interactions mother university manchester professor matthew cobb told guardian']

# %%
# Train Breitbart Model
clf = Pipeline([
    ('vectorizer', CountVectorizer(min_df=5)),
    ('tfidf', TfidfTransformer()),
    ('classifier', LogisticRegression()),
])

clf.fit(X_train, y_train)
y_hat = clf.predict(X_cv)
print(sum(y_hat==y_cv)/len(y_cv))

print(sum(y_hat))
print(sum(y_cv))

probs = clf.predict_proba(X_cv)

TP = sum([y1 == True and y1==y2 for (y1,y2) in zip(y_hat, y_cv)])
FP = sum([y1 == True and y1!=y2 for (y1,y2) in  zip(y_hat, y_cv)])
TN = sum([y1 == False and y1==y2 for (y1,y2) in zip(y_hat, y_cv)])
FN = sum([y1 == False and y1!=y2 for (y1,y2) in zip(y_hat, y_cv)])

precision = TP/(TP+FP)
recall = TP/(TP+FN)
F1 = 2*precision*recall/(precision+recall)

print(precision, recall, F1)

#print(probs[:,1])
# Out:
# 0.840390879479
# 313
# 311
# 0.840255591054 0.845659163987 0.842948717949

# %%
# Train Breitbart Model
clf2 = Pipeline([
    ('vectorizer', CountVectorizer(min_df=5)),
    ('tfidf', TfidfTransformer()),
    ('classifier', LogisticRegression()),
])

clf2.fit(X_train2, y_train2)
y_hat2 = clf.predict(X_cv2)
print(sum(y_hat2==y_cv2)/len(y_cv2))

print(sum(y_hat2))
print(sum(y_cv2))

probs = clf.predict_proba(X_cv2)

TP = sum([y1 == True and y1==y2 for (y1,y2) in zip(y_hat2, y_cv2)])
FP = sum([y1 == True and y1!=y2 for (y1,y2) in  zip(y_hat2, y_cv2)])
TN = sum([y1 == False and y1==y2 for (y1,y2) in zip(y_hat2, y_cv2)])
FN = sum([y1 == False and y1!=y2 for (y1,y2) in zip(y_hat2, y_cv2)])

precision = TP/(TP+FP)
recall = TP/(TP+FN)
F1 = 2*precision*recall/(precision+recall)

print(precision, recall, F1)

#print(probs[:,1])
# Out:
# 0.830618892508
# 313
# 311
# 0.830670926518 0.836012861736 0.833333333333

# %%
def make_coefs_table(model):
    coefs = model.named_steps['classifier'].coef_
    features = model.named_steps['vectorizer'].get_feature_names()

    table = pd.DataFrame({"features": features, "coefficients": coefs.tolist().pop(0)})
    return(table.sort_values('coefficients', ascending = False))

# %%
breitbart_words = make_coefs_table(clf)
breitbart_words = breitbart_words.reset_index(drop=True)
print(breitbart_words[0:20])

x_values = breitbart_words.coefficients[0:20]
y_values = breitbart_words.features[0:20]
y_axis = np.arange(0, 20, 1)

plt.barh(y_axis, x_values, align='edge', color = 'red')
plt.yticks(y_axis, y_values)
plt.gca().invert_yaxis()
#plt.gca().invert_xaxis()
plt.title('Top Words Predicting Breitbart')
plt.show()

x_values = breitbart_words.coefficients[-20:]
y_values = breitbart_words.features[-20:]
y_axis = np.arange(0, 20, 1)

plt.barh(y_axis, x_values, align='edge', color = 'blue')
plt.yticks(y_axis, y_values)
#plt.gca().invert_xaxis()
plt.title('Top Words Predicting Huffington Post')
plt.show()
# Out:
#     coefficients     features
# 0       1.317133       israel
# 1       1.242673         milo
# 2       1.236401   government
# 3       1.232818     migrants
# 4       1.219487           al
# 5       1.140461          gun
# 6       1.138754       police
# 7       1.037359         left
# 8       0.957670          per
# 9       0.932627  immigration
# 10      0.932243        added
# 11      0.922091         here
# 12      0.899539      islamic
# 13      0.887869         wing
# 14      0.883969     european
# 15      0.875490         cent
# 16      0.872933           eu
# 17      0.865217        texas
# 18      0.847644     minister
# 19      0.832311       campus

# %%
probs = clf.predict_proba(X_test)
df = pd.DataFrame({'p': probs[:,1], 'predicted':y_hat, 'actual':y_test, 'text': X_test}).sort_values('p')
misclassified = df[(df.predicted!=df.actual)]
misclassified.head()
# Out:
#     actual         p predicted  \
# 68    True  0.239737     False
# 162   True  0.242600     False
# 377   True  0.260733     False
# 287   True  0.276766     False
# 341   True  0.319056     False
#
#                                                   text
# 68   disastrous first half patriots falcons jumped ...
# 162  mckibben contributed numerous opinion pieces g...
# 377  journalists countrys biggest outlets raked bad...
# 287  for reason room got tv set cnn every day wake ...
# 341  it totally undid could vote trump gayle mccorm...

# %%
import matplotlib.pyplot as plt
import numpy as np

import plotly.plotly as py

h = plt.hist(df.p[df.actual==False], color = 'blue')
b = plt.hist(df.p[df.actual==True], color = 'red')
plt.title("Histogram of  Probabilities")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend(['Huffington', 'Breitbart'])

fig = plt.gcf()
plt.show()

# %%
liberal = pd.read_csv('huffington_words.csv')
conservative = pd.read_csv('breitbart_words.csv')

top_liberal = liberal.features[0:100].tolist()
top_conservative = conservative.features[0:100].tolist()

common = [word for word in top_liberal if word in top_conservative]
unique_conservative = [word for word in top_conservative if word not in top_liberal]
unique_liberal = [word for word in top_liberal if word not in top_conservative]

def list_words(word_list):
    for word in word_list:
        print(word)
print("COMMON", len(common))
list_words(common)  
print("BREITBART", len(unique_conservative))
list_words(unique_conservative)
print("LIBERAL", len(unique_liberal))
list_words(unique_liberal)
# Out:
# COMMON 34
# trumps
# its
# dont
# thats
# hes
# didnt
# were
# im
# theres
# super
# bowl
# doesnt
# theyre
# youre
# feb
# cant
# time
# isnt
# reportedly
# countrys
# think
# the
# lot
# fact
# obamas
# see
# news
# oreilly
# host
# fox
# however
# mental
# reported
# users
# BREITBART 66
# migrants
# mr
# per
# left
# irans
# well
# added
# milo
# here
# continued
# reports
# party
# migrant
# terrorist
# obamacare
# senator
# campus
# police
# cent
# anti
# uk
# soros
# due
# realdonaldtrump
# hamas
# gun
# parliament
# european
# wing
# stated
# respect
# berkeley
# violence
# texas
# emergency
# sanctuary
# gaza
# want
# arrested
# thing
# un
# kelloggs
# islam
# iranian
# cotton
# racist
# islands
# al
# reform
# pope
# right
# isis
# core
# liberals
# com
# baldwin
# and
# to
# article
# de
# saw
# states
# erdogan
# stop
# media
# brexit
# LIBERAL 66
# refugees
# video
# order
# huffpost
# above
# told
# sunday
# presidents
# show
# executive
# check
# weve
# reuters
# posted
# muslim
# post
# pelosi
# clip
# star
# wasnt
# yates
# womens
# know
# below
# awards
# things
# found
# pst
# one
# best
# photo
# season
# grammy
# performance
# signed
# wont
# game
# muslims
# singer
# spicer
# lgbtq
# watch
# patriots
# statement
# last
# according
# heres
# album
# administrations
# fans
# controversial
# really
# ive
# got
# story
# ever
# love
# actually
# undocumented
# green
# grammys
# parents
# acting
# simply
# him
# meyers

# %%
liberal2 = pd.read_csv('huffington_words_w2.csv')
conservative2 = pd.read_csv('breitbart_words_w2.csv')

top_liberal2 = liberal2.features[0:100].tolist()
top_conservative2 = conservative2.features[0:100].tolist()

common = [word for word in top_liberal if word in top_conservative]
unique_conservative = [word for word in top_conservative if word not in top_liberal]
unique_liberal = [word for word in top_liberal if word not in top_conservative]

common_liberal = [word for word in top_liberal if word not in top_liberal2]
common_conservative = [word for word in top_conservative if word not in top_conservative2]


def list_words(word_list):
    for word in word_list:
        print(word)
        
print("COMMON", len(common))
list_words(common)  
print("BREITBART", len(unique_conservative))
list_words(unique_conservative)
print("LIBERAL", len(unique_liberal))
list_words(unique_liberal)

print("COMMON LIBERAL", len(common_liberal))
list_words(unique_liberal)
print("COMMON CONSERVATIVE", len(common_conservative))
list_words(unique_conservative)
# Out:
# COMMON 34
# trumps
# its
# dont
# thats
# hes
# didnt
# were
# im
# theres
# super
# bowl
# doesnt
# theyre
# youre
# feb
# cant
# time
# isnt
# reportedly
# countrys
# think
# the
# lot
# fact
# obamas
# see
# news
# oreilly
# host
# fox
# however
# mental
# reported
# users
# BREITBART 66
# migrants
# mr
# per
# left
# irans
# well
# added
# milo
# here
# continued
# reports
# party
# migrant
# terrorist
# obamacare
# senator
# campus
# police
# cent
# anti
# uk
# soros
# due
# realdonaldtrump
# hamas
# gun
# parliament
# european
# wing
# stated
# respect
# berkeley
# violence
# texas
# emergency
# sanctuary
# gaza
# want
# arrested
# thing
# un
# kelloggs
# islam
# iranian
# cotton
# racist
# islands
# al
# reform
# pope
# right
# isis
# core
# liberals
# com
# baldwin
# and
# to
# article
# de
# saw
# states
# erdogan
# stop
# media
# brexit
# LIBERAL 66
# refugees
# video
# order
# huffpost
# above
# told
# sunday
# presidents
# show
# executive
# check
# weve
# reuters
# posted
# muslim
# post
# pelosi
# clip
# star
# wasnt
# yates
# womens
# know
# below
# awards
# things
# found
# pst
# one
# best
# photo
# season
# grammy
# performance
# signed
# wont
# game
# muslims
# singer
# spicer
# lgbtq
# watch
# patriots
# statement
# last
# according
# heres
# album
# administrations
# fans
# controversial
# really
# ive
# got
# story
# ever
# love
# actually
# undocumented
# green
# grammys
# parents
# acting
# simply
# him
# meyers
# COMMON LIBERAL 28
# refugees
# video
# order
# huffpost
# above
# told
# sunday
# presidents
# show
# executive
# check
# weve
# reuters
# posted
# muslim
# post
# pelosi
# clip
# star
# wasnt
# yates
# womens
# know
# below
# awards
# things
# found
# pst
# one
# best
# photo
# season
# grammy
# performance
# signed
# wont
# game
# muslims
# singer
# spicer
# lgbtq
# watch
# patriots
# statement
# last
# according
# heres
# album
# administrations
# fans
# controversial
# really
# ive
# got
# story
# ever
# love
# actually
# undocumented
# green
# grammys
# parents
# acting
# simply
# him
# meyers
# COMMON CONSERVATIVE 46
# migrants
# mr
# per
# left
# irans
# well
# added
# milo
# here
# continued
# reports
# party
# migrant
# terrorist
# obamacare
# senator
# campus
# police
# cent
# anti
# uk
# soros
# due
# realdonaldtrump
# hamas
# gun
# parliament
# european
# wing
# stated
# respect
# berkeley
# violence
# texas
# emergency
# sanctuary
# gaza
# want
# arrested
# thing
# un
# kelloggs
# islam
# iranian
# cotton
# racist
# islands
# al
# reform
# pope
# right
# isis
# core
# liberals
# com
# baldwin
# and
# to
# article
# de
# saw
# states
# erdogan
# stop
# media
# brexit
